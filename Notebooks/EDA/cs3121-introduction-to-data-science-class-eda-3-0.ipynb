# %% [markdown]
# ## Note
# * **A detailed analysis is given on the report**

# %%
import numpy as np 
import pandas as pd 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/online-payment-intentions/In22-CS3121-Project Dataset.xlsx
# /kaggle/input/online-payment-intentions-preprocessed/df_copy - with platform columns (shortened column names).csv
# /kaggle/input/online-payment-intentions-preprocessed/df_copy - without platform columns.csv
# /kaggle/input/online-payment-intentions-preprocessed/df_copy - with platform columns.csv

# %%
df_copy = pd.read_csv("/kaggle/input/online-payment-intentions-preprocessed/df_copy - with platform columns (shortened column names).csv")

# %%
df_copy2 = df_copy.copy()

# %% [markdown]
# # EDA

# %%
df_copy2 = df_copy2.drop(['platforms_list', 'specialty_platform_list', 'pharmacy_list', 'retailer_list', 'grocery_delivery_list'], axis=1)

# %%
column_info = pd.DataFrame({
    "Column Name": df_copy2.columns,
    "Data Type": df_copy2.dtypes.values
})
pd.set_option('display.max_rows', None) 
print(column_info)
# Out:
#                                            Column Name Data Type
# 0                                           Unnamed: 0     int64
# 1                                               gender     int64
# 2                                                  age     int64
# 3                           highest level of education     int64
# 4                                       marital status     int64
# 5           have used online shopping platforms before     int64
# 6                              professional background     int64
# 7                         general e-commerce platforms    object
# 8                 specialty online stores / automobile    object
# 9                                    online pharmacies    object
# 10                        fashion and beauty retailers    object
# 11                           grocery delivery services    object
# 12   it is easy to navigate through the online plat...     int64
# 13   the online platform provides clear and intuiti...     int64
# 14   it was easy for me to learn how to use the onl...     int64
# 15   i quickly became proficient in using the onlin...     int64
# 16   the instructions provided on the online platfo...     int64
# 17   i can easily follow the instructions given on ...     int64
# 18   the online platform responds quickly to my act...     int64
# 19   i don't experience delays or long waiting time...     int64
# 20   the online platform effectively handles errors...     int64
# 21   i rarely encounter errors or issues when using...     int64
# 22   the online platform offers a wide range of pro...     int64
# 23   i can find the products or services i need on ...     int64
# 24   using the online platform for making purchases...     int64
# 25   the online platform makes it easy to search fo...     int64
# 26   the online platform offers competitive prices,...     int64
# 27   i perceive that using the online platform for ...     int64
# 28   the online platform provides detailed and accu...     int64
# 29   i can easily access user reviews, ratings, and...     int64
# 30   the online platform tailors recommendations, s...     int64
# 31   i feel that the online platform understands my...     int64
# 32   the online platform takes appropriate measures...     int64
# 33   i trust that my personal information will be h...     int64
# 34   the online platform provides secure payment me...     int64
# 35   i trust that my payment details are handled se...     int64
# 36   the online platform provides clear and easily ...     int64
# 37   i feel confident in the online platform's tran...     int64
# 38   i am influenced by recommendations and opinion...     int64
# 39   i consider the experiences and suggestions sha...     int64
# 40   during a crisis, social media platforms, influ...     int64
# 41   i am likely to make online purchases during a ...     int64
# 42   i consider online reviews and ratings when mak...     int64
# 43   positive reviews and high ratings increase my ...     int64
# 44   observing others making online purchases durin...     int64
# 45   i am more likely to make online purchases duri...     int64
# 46   social norms and expectations regarding online...     int64
# 47   i feel pressure to make online purchases durin...     int64
# 48   i am willing to share my own online shopping e...     int64
# 49   sharing information about my online purchases ...     int64
# 50   overall, i have a positive attitude toward onl...     int64
# 51   i believe that online shopping is a practical ...     int64
# 52   i am concerned about the security of my person...     int64
# 53   i am cautious about the reliability and authen...     int64
# 54   have you made online purchases during crisis t...     int64
# 55   overall, i am satisfied with online purchase d...     int64
# 56   i have changed my online shopping behavior dur...     int64
# 57   it was convenient for me to do online shopping...     int64
# 58   i believe that online shopping during a crisis...     int64
# 59                                         ali-express     int64
# 60                                               daraz     int64
# 61                                                ebay     int64
# 62                                               ikman     int64
# 63                                    instagram stores     int64
# 64                                             kapruka     int64
# 65                                               keels     int64
# 66                                         lassana.com     int64
# 67                                              pickme     int64
# 68                                               shein     int64
# 69                                           strong.lk     int64
# 70                                               takas     int64
# 71                                             wishque     int64
# 72                                                 wow     int64
# 73                                              amazon     int64
# 74                                       autolanka.com     int64
# 75                                            ikman.lk     int64
# 76                                   lankavechicle.com     int64
# 77                                           patpat.lk     int64
# 78                                       pricelanka.lk     int64
# 79                                       riyasewana.lk     int64
# 80        specialty online stores / automobile unknown     int64
# 81                                              toyota     int64
# 82           zero specialty online stores / automobile     int64
# 83                                           ceymed.lk     int64
# 84                                          epharma.lk     int64
# 85                                       healthgurd.lk     int64
# 86                                        healthnet.lk     int64
# 87                                     nearby pharmacy     int64
# 88                                no online pharmacies     int64
# 89                             online pharmacy unknown     int64
# 90                                   onlinepharmacy.lk     int64
# 91                                       union chemist     int64
# 92                                             amanthe     int64
# 93                                      carlo clothing     int64
# 94                                            carnage,     int64
# 95                                       chenara dodge     int64
# 96                                                 dsi     int64
# 97                                       fashionbug.lk     int64
# 98                                              gflock     int64
# 99                                 kapruka.com/fashion     int64
# 100                                       kelly felder     int64
# 101                                       kynd fashion     int64
# 102                                  midnightdivas.com     int64
# 103                                             mimosa     int64
# 104                                              moods     int64
# 105                                              moose     int64
# 106                                              nills     int64
# 107                    no fashion and beauty retailers     int64
# 108                                         nolimit.lk     int64
# 109                                       noorareed.lk     int64
# 110                                            odel.lk     int64
# 111                                                s&s     int64
# 112                                  spring and summer     int64
# 113                          tharshana and insta shops     int64
# 114                                  thilakawardana.lk     int64
# 115               unknown fashion and beauty retailers     int64
# 116                                          zigzag.lk     int64
# 117                                          arpico.lk     int64
# 118                                 cargillsonline.com     int64
# 119                                  cinnamonhotel.com     int64
# 120                                         glomark.lk     int64
# 121                 grocery delivery services not used     int64
# 122                                     keellssuper.lk     int64
# 123                                    pickmefoods.com     int64
# 124                                       ubereats.com     int64
# 125                  unknown grocery delivery services     int64

# %%
column_info.to_excel("column_info.xlsx", index=False)

# %%
# Nominal (binary)
binary_features = [
    'have used online shopping platforms before', 'have you made online purchases during crisis time?',
    'ali-express', 'daraz', 'ebay', 'ikman', 'instagram stores', 'kapruka', 'keels', 
    'lassana.com', 'pickme', 'shein', 'strong.lk', 'takas', 'wishque', 'wow',
    'amazon', 'autolanka.com', 'ikman.lk', 'lankavechicle.com', 'patpat.lk', 'pricelanka.lk', 
    'riyasewana.lk', 'specialty online stores / automobile unknown', 'toyota',
    'zero specialty online stores / automobile', 'ceymed.lk', 'epharma.lk', 
    'healthgurd.lk', 'healthnet.lk', 'nearby pharmacy', 'no online pharmacies', 
    'online pharmacy unknown', 'onlinepharmacy.lk', 'union chemist', 'amanthe', 
    'carlo clothing', 'carnage,', 'chenara dodge', 'dsi', 'fashionbug.lk', 'gflock',
    'kapruka.com/fashion', 'kelly felder', 'kynd fashion', 'midnightdivas.com', 'mimosa', 'moods',
    'moose', 'nills', 'no fashion and beauty retailers', 'nolimit.lk', 'noorareed.lk', 'odel.lk',
    's&s', 'spring and summer', 'tharshana and insta shops', 'thilakawardana.lk', 
    'unknown fashion and beauty retailers', 'zigzag.lk', 'arpico.lk', 
    'cargillsonline.com', 'cinnamonhotel.com', 'glomark.lk', 'grocery delivery services not used', 
    'keellssuper.lk', 'pickmefoods.com', 'ubereats.com', 'unknown grocery delivery services'
]

# Nominal (Since "Used", "Not Used", and "Unknown" are used for the EDA)
platform_groups = [
    'general e-commerce platforms', 'specialty online stores / automobile', 'online pharmacies', 
    'fashion and beauty retailers', 'grocery delivery services'
]

# Ordinal (0:4 without a specified interval)
other_features = [
    'it is easy to navigate through the online platform to find the products or services i need',
    'the online platform provides clear and intuitive navigation options',
    'it was easy for me to learn how to use the online platform for making online purchases',
    'i quickly became proficient in using the online platform for making online purchases during a crisis',
    'the instructions provided on the online platform are clear and easy to understand',
    'i can easily follow the instructions given on the online platform for making online purchases',
    'the online platform responds quickly to my actions, such as loading pages and processing transactions.',
    'i don\'t experience delays or long waiting times when using the online platform for making online purchases during a crisis',
    'the online platform effectively handles errors or mistakes, such as providing clear error messages and easy recovery options',
    'i rarely encounter errors or issues when using the online platform for making online purchases during a crisis',
    'the online platform offers a wide range of products and services that meet my needs during a crisis',
    'i can find the products or services i need on the online platform during a crisis',
    'using the online platform for making purchases during a crisis is convenient and saves time',
    'the online platform makes it easy to search for products and complete transactions during a crisis',
    'the online platform offers competitive prices, discounts, or cost-saving benefits during a crisis',
    'i perceive that using the online platform for making purchases during a crisis can help me save money',
    'the online platform provides detailed and accurate product information during a crisis',
    'i can easily access user reviews, ratings, and other relevant information to support my purchase decisions',
    'the online platform tailors recommendations, suggestions, or personalized offers based on my preferences',
    'i feel that the online platform understands my needs and preferences during a crisis',
    'the online platform takes appropriate measures to protect my privacy',
    'i trust that my personal information will be handled securely by the online platform',
    'the online platform provides secure payment methods to protect against fraudulent activities during a crisis',
    'i trust that my payment details are handled securely by the online platform',
    'the online platform provides clear and easily accessible policies regarding data handling, privacy, and security',
    'i feel confident in the online platform\'s transparency regarding its data protection practices',
    'i am influenced by recommendations and opinions from family and friends when making online purchases during a crisis',
    'i consider the experiences and suggestions shared by people i know before making online purchases during a crisis',
    'during a crisis, social media platforms, influencers, and online communities influence my online purchase decisions',
    'i am likely to make online purchases during a crisis based on what i see or learn from social media platforms',
    'i consider online reviews and ratings when making purchasing decisions during a crisis',
    'positive reviews and high ratings increase my confidence in making online purchases during a crisis',
    'observing others making online purchases during a crisis influences my own intention to make similar purchases',
    'i am more likely to make online purchases during a crisis if i see others doing the same',
    'social norms and expectations regarding online shopping during a crisis influence my own intention to make online purchases',
    'i feel pressure to make online purchases during a crisis due to the expectations of others',
    'i am willing to share my own online shopping experiences, recommendations, or opinions with others during a crisis',
    'sharing information about my online purchases during a crisis is important for influencing others\' purchase decisions',
    'overall, i have a positive attitude toward online shopping during a crisis',
    'i believe that online shopping is a practical and efficient way to make purchases during a crisis',
    'i am concerned about the security of my personal and financial information when shopping online during a crisis',
    'i am cautious about the reliability and authenticity of products or services offered by online platforms during a crisis',
    'overall, i am satisfied with online purchase during a crisis?',
    'i have changed my online shopping behavior during a crisis compared to non-crisis periods?',
    'it was convenient for me to do online shopping during a crisis compared to traditional in-store shopping',
    'i believe that online shopping during a crisis offers better value for money compared to traditional shopping methods'
]

# %%
for platform_group in platform_groups:
    unique_values = df_copy2[platform_group].unique()
    print("Unique values of", platform_group, ":\n", unique_values, "\n")
# Out:
# Unique values of general e-commerce platforms :
#  ['daraz, ikman' 'daraz, kapruka, ikman' 'daraz, wow' 'daraz, kapruka'
#  'kapruka, ikman, takas, wishque' 'daraz, kapruka, ikman, takas, wow'
#  'kapruka, ali-express' 'daraz' 'daraz, kapruka, ikman, wishque'
#  'daraz, ikman, wow' 'ikman' 'kapruka' 'daraz, ali-express'
#  'daraz, strong.lk' 'ali-express, ebay' 'kapruka, ikman' 'daraz, keels'
#  'daraz, ikman, takas, wow' 'daraz, keels, wishque'
#  'daraz, kapruka, ikman, amazon ,ebay' 'kapruka, ikman, takas, wow'
#  'kapruka, ikman, takas' 'daraz, kapruka, ikman, takas'
#  'daraz, kapruka, pickme' 'daraz, kapruka, wow' 'ebay' 'daraz, wishque'
#  'daraz, kapruka, lassana.com' 'daraz, takas, wow'
#  'daraz, kapruka, ikman, wow' 'daraz, ikman, takas'
#  'daraz, instagram stores' 'shein']
#
# Unique values of specialty online stores / automobile :
#  ['specialty online stores / automobile unknown' 'patpat.lk'
#  'patpat.lk, riyasewana.lk' 'lankavechicle.com' 'riyasewana.lk'
#  'autolanka.com' 'autolanka.com, riyasewana.lk'
#  'patpat.lk, riyasewana.lk, lankavechicle.com' 'pricelanka.lk'
#  'riyasewana.lk, lankavechicle.com'
#  'autolanka.com, pricelanka.lk, patpat.lk, riyasewana.lk, lankavechicle.com'
#  'autolanka.com, toyota' 'zero specialty online stores / automobile'
#  'autolanka.com, patpat.lk' 'ikman.lk'
#  'autolanka.com, patpat.lk, riyasewana.lk' 'pricelanka.lk, patpat.lk'
#  'amazon' 'autolanka.com, riyasewana.lk, ikman.lk'
#  'autolanka.com, pricelanka.lk']
#
# Unique values of online pharmacies :
#  ['online pharmacy unknown' 'epharma.lk, onlinepharmacy.lk'
#  'healthgurd.lk, onlinepharmacy.lk' 'onlinepharmacy.lk'
#  'epharma.lk, ceymed.lk' 'healthgurd.lk, ceymed.lk' 'healthgurd.lk'
#  'union chemist' 'epharma.lk' 'ceymed.lk'
#  'epharma.lk, healthgurd.lk, ceymed.lk' 'healthnet.lk'
#  'epharma.lk, healthgurd.lk, onlinepharmacy.lk' 'no online pharmacies'
#  'nearby pharmacy'
#  'epharma.lk, healthgurd.lk, healthnet.lk, onlinepharmacy.lk, ceymed.lk'
#  'onlinepharmacy.lk, ceymed.lk'
#  'epharma.lk, healthgurd.lk, healthnet.lk, ceymed.lk'
#  'healthgurd.lk, healthnet.lk'
#  'healthgurd.lk, healthnet.lk, onlinepharmacy.lk'
#  'healthgurd.lk, ceymed.lk, nearby pharmacy']
#
# Unique values of fashion and beauty retailers :
#  ['unknown fashion and beauty retailers'
#  'kapruka.com/fashion, fashionbug.lk, odel.lk'
#  'thilakawardana.lk, fashionbug.lk, odel.lk, noorareed.lk' 'fashionbug.lk'
#  'fashionbug.lk, midnightdivas.com'
#  'kapruka.com/fashion, thilakawardana.lk, fashionbug.lk, odel.lk'
#  'kapruka.com/fashion, odel.lk' 'odel.lk' 'kelly felder'
#  'odel.lk, zigzag.lk' 'thilakawardana.lk, fashionbug.lk'
#  'kapruka.com/fashion' 'fashionbug.lk, odel.lk'
#  'odel.lk, midnightdivas.com' 'fashionbug.lk, odel.lk, midnightdivas.com'
#  'midnightdivas.com' 'kapruka.com/fashion, odel.lk, midnightdivas.com'
#  'kapruka.com/fashion, fashionbug.lk' 'thilakawardana.lk'
#  'thilakawardana.lk, fashionbug.lk, odel.lk'
#  'kapruka.com/fashion, thilakawardana.lk, odel.lk' 'moose' 'chenara dodge'
#  'dsi' 'no fashion and beauty retailers'
#  'kapruka.com/fashion, thilakawardana.lk, fashionbug.lk, odel.lk, midnightdivas.com'
#  'thilakawardana.lk, odel.lk' 'nills, chenara dodge' 'spring and summer'
#  'fashionbug.lk, nolimit.lk, gflock'
#  'thilakawardana.lk, midnightdivas.com' 'moods, amanthe' 's&s'
#  'carlo clothing' 'midnightdivas.com, tharshana and insta shops'
#  'thilakawardana.lk, fashionbug.lk, odel.lk, midnightdivas.com'
#  'kapruka.com/fashion, kelly felder'
#  'kapruka.com/fashion, kynd fashion, carnage,'
#  'kapruka.com/fashion, thilakawardana.lk'
#  'kapruka.com/fashion, fashionbug.lk, odel.lk, kelly felder, mimosa'
#  'kapruka.com/fashion, gflock, kelly felder'
#  'kapruka.com/fashion, gflock, spring and summer']
#
# Unique values of grocery delivery services :
#  ['ubereats.com' 'ubereats.com, pickmefoods.com, keellssuper.lk'
#  'ubereats.com, pickmefoods.com'
#  'ubereats.com, pickmefoods.com, keellssuper.lk, arpico.lk'
#  'ubereats.com, pickmefoods.com, arpico.lk' 'keellssuper.lk, arpico.lk'
#  'ubereats.com, keellssuper.lk' 'unknown grocery delivery services'
#  'keellssuper.lk' 'pickmefoods.com' 'pickmefoods.com, keellssuper.lk'
#  'ubereats.com, pickmefoods.com, keellssuper.lk, arpico.lk, glomark.lk'
#  'ubereats.com, pickmefoods.com, keellssuper.lk, arpico.lk, cinnamonhotel.com'
#  'keellssuper.lk, arpico.lk, cinnamonhotel.com'
#  'ubereats.com, pickmefoods.com, cinnamonhotel.com'
#  'ubereats.com, pickmefoods.com, keellssuper.lk, glomark.lk'
#  'ubereats.com, pickmefoods.com, keellssuper.lk, cinnamonhotel.com'
#  'ubereats.com, cargillsonline.com' 'keellssuper.lk, cargillsonline.com'
#  'ubereats.com, keellssuper.lk, arpico.lk' 'ubereats.com, arpico.lk'
#  'grocery delivery services not used' 'keellssuper.lk, cinnamonhotel.com'
#  'arpico.lk']

# %% [markdown]
# # Gender

# %%
import seaborn as sns
import matplotlib.pyplot as plt

gender_map = {0: 'Male', 1: 'Female', -1: 'Prefer not to say'}
df_copy2['gender_label'] = df_copy2['gender'].map(gender_map)

# Countplot using seaborn
plt.figure(figsize=(6, 4))
sns.countplot(data=df_copy2, x='gender_label', palette=['skyblue', 'lightpink', 'gray'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
output_dir = '/kaggle/working/gender'
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# * **Gender is Nominal**

# %% [markdown]
# ##  Gender vs Binary Features

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import zipfile
import warnings

warnings.filterwarnings('ignore')

output_dir = '/kaggle/working/gender/binary_features/plots'
os.makedirs(output_dir, exist_ok=True)

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')
    
gender_map = {0: 'Male', 1: 'Female', -1: 'Prefer not to say'}
df_copy2['gender_label'] = df_copy2['gender'].map(gender_map)

binary_contingency_tables = []

for feature in binary_features:
    try:
        contingency_table = pd.crosstab(df_copy2['gender_label'], df_copy2[feature])
        #print(f"Contingency Table for {feature} created")

        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Feature'] = feature
        binary_contingency_tables.append(contingency_table_reset)

        plt.figure(figsize=(8, 6))
        sns.countplot(data=df_copy2, x='gender_label', hue=feature, palette='Set2', order=['Male', 'Female', 'Prefer not to say'])
        plt.title(f'Gender vs. {feature} Usage')
        plt.xlabel('Gender')
        plt.ylabel('Count')
        plt.legend(['Not Used', 'Used'])
        plt.tight_layout()
        filename = f"{output_dir}/gender_vs_{sanitize_filename(feature)}_stacked_bar.png"
        plt.savefig(filename)
        plt.close()
        print(f"Saved plot: {filename}")
    except Exception as e:
        print(f"Failed to save plot for {feature}: {e}")
        plt.close()
        continue

if binary_contingency_tables:
    all_binary_tables_df = pd.concat(binary_contingency_tables, ignore_index=True)
    cols = ['Feature'] + [col for col in all_binary_tables_df.columns if col != 'Feature']
    all_binary_tables_df = all_binary_tables_df[cols]
    output_xlsx = '/kaggle/working/gender/binary_features/binary_contingency_tables.xlsx'
    all_binary_tables_df.to_excel(output_xlsx, index=False)
    print(f"Saved binary contingency tables to: {output_xlsx}")
else:
    print("No binary contingency tables to save.")

zip_filename = '/kaggle/working/gender/binary_features/plots-binary.zip'
print(f"Creating ZIP file: {zip_filename}...")

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.png'):
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, '/kaggle/working/')
                zipf.write(file_path, arcname)

print(f"ZIP file created: {zip_filename}")

print("EDA for Age vs. Binary Features completed. Plots saved as PNG files")
# Out:
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_have_used_online_shopping_platforms_before_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_have_you_made_online_purchases_during_crisis_time__stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_ali-express_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_daraz_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_ebay_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_ikman_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_instagram_stores_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_kapruka_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_keels_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_lassana_com_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_pickme_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_shein_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_strong_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_takas_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_wishque_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_wow_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_amazon_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_autolanka_com_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_ikman_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_lankavechicle_com_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_patpat_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_pricelanka_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_riyasewana_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_specialty_online_stores___automobile_unknown_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_toyota_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_zero_specialty_online_stores___automobile_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_ceymed_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_epharma_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_healthgurd_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_healthnet_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_nearby_pharmacy_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_no_online_pharmacies_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_online_pharmacy_unknown_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_onlinepharmacy_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_union_chemist_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_amanthe_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_carlo_clothing_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_carnage__stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_chenara_dodge_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_dsi_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_fashionbug_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_gflock_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_kapruka_com_fashion_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_kelly_felder_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_kynd_fashion_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_midnightdivas_com_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_mimosa_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_moods_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_moose_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_nills_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_no_fashion_and_beauty_retailers_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_nolimit_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_noorareed_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_odel_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_s_s_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_spring_and_summer_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_tharshana_and_insta_shops_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_thilakawardana_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_unknown_fashion_and_beauty_retailers_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_zigzag_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_arpico_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_cargillsonline_com_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_cinnamonhotel_com_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_glomark_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_grocery_delivery_services_not_used_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_keellssuper_lk_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_pickmefoods_com_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_ubereats_com_stacked_bar.png
# Saved plot: /kaggle/working/gender/binary_features/plots/gender_vs_unknown_grocery_delivery_services_stacked_bar.png
# Saved binary contingency tables to: /kaggle/working/gender/binary_features/binary_contingency_tables.xlsx
# Creating ZIP file: /kaggle/working/gender/binary_features/plots-binary.zip...
# ZIP file created: /kaggle/working/gender/binary_features/plots-binary.zip
# EDA for Age vs. Binary Features completed. Plots saved as PNG files

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import warnings
import shutil
import zipfile
import numpy as np
from scipy.stats import chi2_contingency

warnings.filterwarnings('ignore')

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')

# Function to perform chi-squared test with expected frequency checks
def chi_square_test(contingency_table):
    if contingency_table.size > 0 and contingency_table.shape[0] > 1 and contingency_table.shape[1] > 1:
        chi2, p, dof, expected = chi2_contingency(contingency_table)
        if (expected < 1).any():
            print("Skipping chi-squared test: Expected frequencies contain values less than 1.")
            return None, None
        if (expected < 5).any():
            print("Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.")
        return chi2, p
    return None, None

def cramers_v(contingency_table, chi2):
    n = contingency_table.sum().sum()
    min_dim = min(contingency_table.shape) - 1
    return np.sqrt(chi2 / (n * min_dim))

df_working = df_copy2.copy()

binary_contingency_tables = {}
p_values_dict = {}

print("=== Chi-Squared Tests for Binary Features ===")
for feature in binary_features:
    if feature not in df_working.columns:
        print(f"Column '{feature}' not found in df_copy2. Skipping...")
        continue

    try:
        if not df_working[feature].isin([0, 1]).all():
            print(f"Feature '{feature}' contains non-binary values. Skipping...")
            continue

        contingency_table = pd.crosstab(df_working['gender_label'], df_working[feature])
        #print(f"\nContingency Table for {feature}:\n{contingency_table}\n")

        chi2, p_value = chi_square_test(contingency_table)
        if p_value is not None:
            p_values_dict[feature] = p_value
            print(f"Chi-squared p-value for {feature}: {p_value:.3f}")
            # Compute Cramér's V
            cramer_v = cramers_v(contingency_table, chi2)
            print(f"Cramér's V for {feature}: {cramer_v:.3f}\n")
        else:
            print(f"Cannot compute chi-squared p-value for {feature}: insufficient data in contingency table\n")

        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Feature'] = feature
        binary_contingency_tables[feature] = contingency_table_reset
        
    except Exception as e:
        print(f"Failed to process feature '{feature}': {e}")
        continue

if p_values_dict:
    print("\n=== FDR Correction Results ===")
    p_values = pd.Series(p_values_dict)
    m = len(p_values)
    sorted_p = p_values.sort_values()
    ranks = range(1, m + 1)
    fdr_thresholds = [(i * 0.05) / m for i in ranks]

    print("p-values and FDR Thresholds:")
    for rank, (feature, p_val) in enumerate(sorted_p.items(), 1):
        threshold = fdr_thresholds[rank - 1]
        print(f"Rank {rank}: {feature} (p-value: {p_val:.3f}, FDR threshold: {threshold:.4f})")

    significant = sorted_p <= fdr_thresholds
    max_significant_idx = significant[::-1].idxmax() if significant.any() else None

    print("\nSignificance After FDR Correction:")
    for feature, p_val in sorted_p.items():
        if max_significant_idx and p_val <= sorted_p[max_significant_idx]:
            print(f"Significant association detected for {feature} after FDR correction (p-value: {p_val:.3f})")
        else:
            print(f"No significant association for {feature} after FDR correction (p-value: {p_val:.3f})")
# Out:
# === Chi-Squared Tests for Binary Features ===
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for have used online shopping platforms before: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for have you made online purchases during crisis time?: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for ali-express: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for daraz: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for ebay: insufficient data in contingency table
#
# Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.
# Chi-squared p-value for ikman: 0.769
# Cramér's V for ikman: 0.025
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for instagram stores: insufficient data in contingency table
#
# Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.
# Chi-squared p-value for kapruka: 0.055
# Cramér's V for kapruka: 0.084
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for keels: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for lassana.com: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for pickme: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for shein: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for strong.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for takas: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for wishque: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for wow: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for amazon: insufficient data in contingency table
#
# Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.
# Chi-squared p-value for autolanka.com: 0.051
# Cramér's V for autolanka.com: 0.085
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for ikman.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for lankavechicle.com: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for patpat.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for pricelanka.lk: insufficient data in contingency table
#
# Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.
# Chi-squared p-value for riyasewana.lk: 0.000
# Cramér's V for riyasewana.lk: 0.264
#
# Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.
# Chi-squared p-value for specialty online stores / automobile unknown: 0.341
# Cramér's V for specialty online stores / automobile unknown: 0.051
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for toyota: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for zero specialty online stores / automobile: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for ceymed.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for epharma.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for healthgurd.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for healthnet.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for nearby pharmacy: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for no online pharmacies: insufficient data in contingency table
#
# Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.
# Chi-squared p-value for online pharmacy unknown: 0.000
# Cramér's V for online pharmacy unknown: 0.217
#
# Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.
# Chi-squared p-value for onlinepharmacy.lk: 0.000
# Cramér's V for onlinepharmacy.lk: 0.149
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for union chemist: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for amanthe: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for carlo clothing: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for carnage,: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for chenara dodge: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for dsi: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for fashionbug.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for gflock: insufficient data in contingency table
#
# Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.
# Chi-squared p-value for kapruka.com/fashion: 0.000
# Cramér's V for kapruka.com/fashion: 0.155
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for kelly felder: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for kynd fashion: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for midnightdivas.com: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for mimosa: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for moods: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for moose: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for nills: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for no fashion and beauty retailers: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for nolimit.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for noorareed.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for odel.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for s&s: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for spring and summer: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for tharshana and insta shops: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for thilakawardana.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for unknown fashion and beauty retailers: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for zigzag.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for arpico.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for cargillsonline.com: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for cinnamonhotel.com: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for glomark.lk: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for grocery delivery services not used: insufficient data in contingency table
#
# Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.
# Chi-squared p-value for keellssuper.lk: 0.000
# Cramér's V for keellssuper.lk: 0.200
#
# Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.
# Chi-squared p-value for pickmefoods.com: 0.000
# Cramér's V for pickmefoods.com: 0.186
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for ubereats.com: insufficient data in contingency table
#
# Skipping chi-squared test: Expected frequencies contain values less than 1.
# Cannot compute chi-squared p-value for unknown grocery delivery services: insufficient data in contingency table
#
#
# === FDR Correction Results ===
# p-values and FDR Thresholds:
# Rank 1: riyasewana.lk (p-value: 0.000, FDR threshold: 0.0050)
# Rank 2: online pharmacy unknown (p-value: 0.000, FDR threshold: 0.0100)
# Rank 3: keellssuper.lk (p-value: 0.000, FDR threshold: 0.0150)
# Rank 4: pickmefoods.com (p-value: 0.000, FDR threshold: 0.0200)
# Rank 5: kapruka.com/fashion (p-value: 0.000, FDR threshold: 0.0250)
# Rank 6: onlinepharmacy.lk (p-value: 0.000, FDR threshold: 0.0300)
# Rank 7: autolanka.com (p-value: 0.051, FDR threshold: 0.0350)
# Rank 8: kapruka (p-value: 0.055, FDR threshold: 0.0400)
# Rank 9: specialty online stores / automobile unknown (p-value: 0.341, FDR threshold: 0.0450)
# Rank 10: ikman (p-value: 0.769, FDR threshold: 0.0500)
#
# Significance After FDR Correction:
# Significant association detected for riyasewana.lk after FDR correction (p-value: 0.000)
# Significant association detected for online pharmacy unknown after FDR correction (p-value: 0.000)
# Significant association detected for keellssuper.lk after FDR correction (p-value: 0.000)
# Significant association detected for pickmefoods.com after FDR correction (p-value: 0.000)
# Significant association detected for kapruka.com/fashion after FDR correction (p-value: 0.000)
# Significant association detected for onlinepharmacy.lk after FDR correction (p-value: 0.000)
# No significant association for autolanka.com after FDR correction (p-value: 0.051)
# No significant association for kapruka after FDR correction (p-value: 0.055)
# No significant association for specialty online stores / automobile unknown after FDR correction (p-value: 0.341)
# No significant association for ikman after FDR correction (p-value: 0.769)

# %% [markdown]
# ## Other Features

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import warnings
import zipfile

warnings.filterwarnings('ignore')

output_dir = '/kaggle/working/gender/other_features/plots'
os.makedirs(output_dir, exist_ok=True)

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')

# Mapping for other_features values (1 to 5)
agreement_mapping = {
    0: 'Strongly Disagree',
    1: 'Disagree',
    2: 'Neutral',
    3: 'Agree',
    4: 'Strongly Agree'
}

# Define the correct order of agreement levels
agreement_order = ['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree']

other_contingency_tables = []  

df_copy2_mapped = df_copy2.copy()
for feature in other_features:
    df_copy2_mapped[feature] = df_copy2_mapped[feature].map(agreement_mapping)
    df_copy2_mapped[feature] = pd.Categorical(df_copy2_mapped[feature], categories=agreement_order, ordered=True)

for feature in other_features:
    try:
        contingency_table = pd.crosstab(df_copy2['gender_label'], df_copy2_mapped[feature])
        #print(f"Contingency Table for {feature} created")
        
        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Feature'] = feature
        other_contingency_tables.append(contingency_table_reset)

        plt.figure(figsize=(8, 6))
        sns.countplot(data=df_copy2_mapped, x='gender_label', hue=feature, hue_order=agreement_order, palette='Set3')
        plt.title(f'Gender vs. {feature} Agreement Levels')
        plt.xlabel('Gender')
        plt.ylabel('Count')
        plt.legend(title='Agreement Level')
        plt.tight_layout()
        filename = f"{output_dir}/gender_vs_{sanitize_filename(feature)}_stacked_bar.png"
        plt.savefig(filename)
        plt.close()
        print(f"Saved plot: {filename}")
    except Exception as e:
        print(f"Failed to save plot for {feature}: {e}")
        plt.close()
        continue

if other_contingency_tables:
    all_other_tables_df = pd.concat(other_contingency_tables, ignore_index=True)
    cols = ['Feature'] + [col for col in all_other_tables_df.columns if col != 'Feature']
    all_other_tables_df = all_other_tables_df[cols]
    output_xlsx = '/kaggle/working/gender/other_features/other_contingency_tables.xlsx'
    all_other_tables_df.to_excel(output_xlsx, index=False)
    #print(f"Saved other features contingency tables to: {output_xlsx}")
else:
    print("No other features contingency tables to save.")

zip_filename = '/kaggle/working/gender/other_features/plots.zip'
print(f"Creating ZIP file: {zip_filename}...")

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.png'):  
                file_path = os.path.join(root, file)
                
                arcname = os.path.relpath(file_path, '/kaggle/working/')
                zipf.write(file_path, arcname)

print(f"ZIP file created: {zip_filename}")

print("EDA completed. Plots saved as PNG files")
# Out:
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_it_is_easy_to_navigate_through_the_online_platform_to_find_the_products_or_services_i_need_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_the_online_platform_provides_clear_and_intuitive_navigation_options_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_it_was_easy_for_me_to_learn_how_to_use_the_online_platform_for_making_online_purchases_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_quickly_became_proficient_in_using_the_online_platform_for_making_online_purchases_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_the_instructions_provided_on_the_online_platform_are_clear_and_easy_to_understand_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_can_easily_follow_the_instructions_given_on_the_online_platform_for_making_online_purchases_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_the_online_platform_responds_quickly_to_my_actions__such_as_loading_pages_and_processing_transactions__stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_don_t_experience_delays_or_long_waiting_times_when_using_the_online_platform_for_making_online_purchases_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_the_online_platform_effectively_handles_errors_or_mistakes__such_as_providing_clear_error_messages_and_easy_recovery_options_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_rarely_encounter_errors_or_issues_when_using_the_online_platform_for_making_online_purchases_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_the_online_platform_offers_a_wide_range_of_products_and_services_that_meet_my_needs_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_can_find_the_products_or_services_i_need_on_the_online_platform_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_using_the_online_platform_for_making_purchases_during_a_crisis_is_convenient_and_saves_time_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_the_online_platform_makes_it_easy_to_search_for_products_and_complete_transactions_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_the_online_platform_offers_competitive_prices__discounts__or_cost-saving_benefits_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_perceive_that_using_the_online_platform_for_making_purchases_during_a_crisis_can_help_me_save_money_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_the_online_platform_provides_detailed_and_accurate_product_information_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_can_easily_access_user_reviews__ratings__and_other_relevant_information_to_support_my_purchase_decisions_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_the_online_platform_tailors_recommendations__suggestions__or_personalized_offers_based_on_my_preferences_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_feel_that_the_online_platform_understands_my_needs_and_preferences_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_the_online_platform_takes_appropriate_measures_to_protect_my_privacy_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_trust_that_my_personal_information_will_be_handled_securely_by_the_online_platform_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_the_online_platform_provides_secure_payment_methods_to_protect_against_fraudulent_activities_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_trust_that_my_payment_details_are_handled_securely_by_the_online_platform_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_the_online_platform_provides_clear_and_easily_accessible_policies_regarding_data_handling__privacy__and_security_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_feel_confident_in_the_online_platform_s_transparency_regarding_its_data_protection_practices_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_am_influenced_by_recommendations_and_opinions_from_family_and_friends_when_making_online_purchases_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_consider_the_experiences_and_suggestions_shared_by_people_i_know_before_making_online_purchases_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_during_a_crisis__social_media_platforms__influencers__and_online_communities_influence_my_online_purchase_decisions_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_am_likely_to_make_online_purchases_during_a_crisis_based_on_what_i_see_or_learn_from_social_media_platforms_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_consider_online_reviews_and_ratings_when_making_purchasing_decisions_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_positive_reviews_and_high_ratings_increase_my_confidence_in_making_online_purchases_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_observing_others_making_online_purchases_during_a_crisis_influences_my_own_intention_to_make_similar_purchases_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_am_more_likely_to_make_online_purchases_during_a_crisis_if_i_see_others_doing_the_same_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_social_norms_and_expectations_regarding_online_shopping_during_a_crisis_influence_my_own_intention_to_make_online_purchases_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_feel_pressure_to_make_online_purchases_during_a_crisis_due_to_the_expectations_of_others_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_am_willing_to_share_my_own_online_shopping_experiences__recommendations__or_opinions_with_others_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_sharing_information_about_my_online_purchases_during_a_crisis_is_important_for_influencing_others__purchase_decisions_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_overall__i_have_a_positive_attitude_toward_online_shopping_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_believe_that_online_shopping_is_a_practical_and_efficient_way_to_make_purchases_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_am_concerned_about_the_security_of_my_personal_and_financial_information_when_shopping_online_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_am_cautious_about_the_reliability_and_authenticity_of_products_or_services_offered_by_online_platforms_during_a_crisis_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_overall__i_am_satisfied_with_online_purchase_during_a_crisis__stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_have_changed_my_online_shopping_behavior_during_a_crisis_compared_to_non-crisis_periods__stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_it_was_convenient_for_me_to_do_online_shopping_during_a_crisis_compared_to_traditional_in-store_shopping_stacked_bar.png
# Saved plot: /kaggle/working/gender/other_features/plots/gender_vs_i_believe_that_online_shopping_during_a_crisis_offers_better_value_for_money_compared_to_traditional_shopping_methods_stacked_bar.png
# Creating ZIP file: /kaggle/working/gender/other_features/plots.zip...
# ZIP file created: /kaggle/working/gender/other_features/plots.zip
# EDA completed. Plots saved as PNG files

# %% [markdown]
# ## Platform Groups

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import warnings
import shutil
import zipfile

warnings.filterwarnings('ignore')

output_dir = '/kaggle/working/gender/platform_groups/plots'
os.makedirs(output_dir, exist_ok=True)

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')

# Define the "not used" values for each group. Unknown is not grouped as "not used"
not_used_values = {
    'general e-commerce platforms': None,  # No explicit "not used" value
    'specialty online stores / automobile': ['zero specialty online stores / automobile'],
    'online pharmacies': ['no online pharmacies'],
    'fashion and beauty retailers': ['no fashion and beauty retailers'],
    'grocery delivery services': ['grocery delivery services not used']
}

# Define the "unknown" values for each group
unknown_values = {
    'general e-commerce platforms': ['unknown'],  # Check for empty-like strings
    'specialty online stores / automobile': ['specialty online stores / automobile unknown'],
    'online pharmacies': ['online pharmacy unknown'],
    'fashion and beauty retailers': ['unknown fashion and beauty retailers'],
    'grocery delivery services': ['unknown grocery delivery services']
}

df_working = df_copy2.copy()

platform_contingency_tables = {}

# Process each platform group
for group in platform_groups:
    if group not in df_working.columns:
        print(f"Column '{group}' not found in df_copy2. Skipping...")
        continue

    try:
        # 0 (Not Used), 1 (Used), 2 (Unknown)
        group_usage_column = f"{group} Usage"
        not_used = not_used_values.get(group, [])
        unknown = unknown_values.get(group, [])
        
        # Convert not_used and unknown lists to lowercase for comparison
        not_used_lower = [val.lower() for val in not_used] if not_used else []
        unknown_lower = [val.lower() for val in unknown] if unknown else []

        # If no explicit "not used" value, assume empty-like strings mean not used
        if not_used is None:
            df_working[group_usage_column] = df_working[group].apply(
                lambda x: 0 if pd.isna(x) or str(x).strip().lower() == '' else
                         2 if str(x).strip().lower() in unknown_lower else 1
            )
        else:
            df_working[group_usage_column] = df_working[group].apply(
                lambda x: 0 if pd.isna(x) or str(x).strip().lower() in not_used_lower else
                         2 if str(x).strip().lower() in unknown_lower else 1
            )

        # For debugging
        # print(f"\nValue counts for {group_usage_column}:\n", df_working[group_usage_column].value_counts())

        contingency_table = pd.crosstab(df_working['gender_label'], df_working[group_usage_column])
        #print(f"\nContingency Table for {group} created")

        # Add group name as a column and store
        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Group'] = group
        platform_contingency_tables[group] = contingency_table_reset

        # Visualize using stacked bar plot with explicit hue_order
        plt.figure(figsize=(8, 6))
        sns.countplot(data=df_working, x='gender_label', hue=group_usage_column, hue_order=[0, 1, 2], palette='Set2')
        plt.title(f'Gender vs. {group} Usage')
        plt.xlabel('Gender')
        plt.ylabel('Count')
        plt.legend(['Not Used', 'Used', 'Unknown'])
        plt.tight_layout()
        filename = f"{output_dir}/gender_vs_{sanitize_filename(group)}_usage_stacked_bar.png"
        plt.savefig(filename)
        plt.close()
        print(f"Saved plot: {filename}")
        
    except Exception as e:
        print(f"Failed to process group '{group}': {e}")
        plt.close()
        continue

output_xlsx = '/kaggle/working/gender/platform_groups/platform_contingency_tables.xlsx'
with pd.ExcelWriter(output_xlsx, engine='openpyxl') as writer:
    for group_name, contingency_table in platform_contingency_tables.items():
        cols = ['Group'] + [col for col in contingency_table.columns if col != 'Group']
        contingency_table = contingency_table[cols]
        sheet_name = sanitize_filename(group_name)[:31]  # Excel sheet names must be <= 31 characters
        contingency_table.to_excel(writer, sheet_name=sheet_name, index=False)
        #print(f"Saved contingency table for {group_name} to sheet '{sheet_name}' in: {output_xlsx}")

zip_filename = '/kaggle/working/gender/platform_groups/plots_grouped_platforms.zip'
print(f"Creating ZIP file: {zip_filename}...")

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.png'): 
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, '/kaggle/working/')
                zipf.write(file_path, arcname)

print(f"ZIP file created: {zip_filename}")

print("EDA for platform groups completed")
# Out:
# Saved plot: /kaggle/working/gender/platform_groups/plots/gender_vs_general_e-commerce_platforms_usage_stacked_bar.png
# Saved plot: /kaggle/working/gender/platform_groups/plots/gender_vs_specialty_online_stores___automobile_usage_stacked_bar.png
# Saved plot: /kaggle/working/gender/platform_groups/plots/gender_vs_online_pharmacies_usage_stacked_bar.png
# Saved plot: /kaggle/working/gender/platform_groups/plots/gender_vs_fashion_and_beauty_retailers_usage_stacked_bar.png
# Saved plot: /kaggle/working/gender/platform_groups/plots/gender_vs_grocery_delivery_services_usage_stacked_bar.png
# Creating ZIP file: /kaggle/working/gender/platform_groups/plots_grouped_platforms.zip...
# ZIP file created: /kaggle/working/gender/platform_groups/plots_grouped_platforms.zip
# EDA for platform groups completed

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import warnings
import shutil
import zipfile
from scipy.stats import chi2_contingency

warnings.filterwarnings('ignore')

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')

# Function to perform chi-squared test
def chi_square_test(contingency_table):
    if contingency_table.size > 0 and contingency_table.shape[0] > 1 and contingency_table.shape[1] > 1:
        _, p, _, _ = chi2_contingency(contingency_table)
        return p
    return None

not_used_values = {
    'general e-commerce platforms': None,
    'specialty online stores / automobile': ['zero specialty online stores / automobile'],
    'online pharmacies': ['no online pharmacies'],
    'fashion and beauty retailers': ['no fashion and beauty retailers'],
    'grocery delivery services': ['grocery delivery services not used']
}

unknown_values = {
    'general e-commerce platforms': ['unknown'],
    'specialty online stores / automobile': ['specialty online stores / automobile unknown'],
    'online pharmacies': ['online pharmacy unknown'],
    'fashion and beauty retailers': ['unknown fashion and beauty retailers'],
    'grocery delivery services': ['unknown grocery delivery services']
}

df_working = df_copy2.copy()

platform_contingency_tables = {}
p_values_dict = {}

# Analyze Platform Groups
print("=== Chi-Squared Tests for Platform Groups ===")
for group in platform_groups:
    if group not in df_working.columns:
        print(f"Column '{group}' not found in df_copy2. Skipping...")
        continue

    try:
        # 0 (Not Used), 1 (Used), 2 (Unknown)
        group_usage_column = f"{group} Usage"
        not_used = not_used_values.get(group, [])
        unknown = unknown_values.get(group, [])
        
        not_used_lower = [val.lower() for val in not_used] if not_used else []
        unknown_lower = [val.lower() for val in unknown] if unknown else []

        if not_used is None:
            df_working[group_usage_column] = df_working[group].apply(
                lambda x: 0 if pd.isna(x) or str(x).strip().lower() == '' else
                         2 if str(x).strip().lower() in unknown_lower else 1
            )
        else:
            df_working[group_usage_column] = df_working[group].apply(
                lambda x: 0 if pd.isna(x) or str(x).strip().lower() in not_used_lower else
                         2 if str(x).strip().lower() in unknown_lower else 1
            )

        contingency_table = pd.crosstab(df_working['gender_label'], df_working[group_usage_column])

        p_value = chi_square_test(contingency_table)
        if p_value is not None:
            p_values_dict[group] = p_value
            print(f"Chi-squared p-value for {group} Usage: {p_value:.3f}")
        else:
            print(f"Cannot compute chi-squared p-value for {group}: insufficient data in contingency table")

        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Group'] = group
        platform_contingency_tables[group] = contingency_table_reset
        
    except Exception as e:
        print(f"Failed to process group '{group}': {e}")
        continue

# Apply FDR correction
if p_values_dict:
    print("\n=== FDR Correction Results ===")
    p_values = pd.Series(p_values_dict)
    m = len(p_values)
    sorted_p = p_values.sort_values()
    ranks = range(1, m + 1)
    fdr_thresholds = [(i * 0.05) / m for i in ranks]
    significant = sorted_p <= fdr_thresholds
    max_significant_idx = significant[::-1].idxmax() if significant.any() else None

    for group, p_val in sorted_p.items():
        if max_significant_idx and p_val <= sorted_p[max_significant_idx]:
            print(f"Significant association detected for {group} Usage after FDR correction (p-value: {p_val:.3f})\n")
        else:
            print(f"No significant association for {group} Usage after FDR correction (p-value: {p_val:.3f})\n")
# Out:
# === Chi-Squared Tests for Platform Groups ===
# Cannot compute chi-squared p-value for general e-commerce platforms: insufficient data in contingency table
# Chi-squared p-value for specialty online stores / automobile Usage: 0.156
# Chi-squared p-value for online pharmacies Usage: 0.000
# Chi-squared p-value for fashion and beauty retailers Usage: 0.000
# Chi-squared p-value for grocery delivery services Usage: 0.000
#
# === FDR Correction Results ===
# Significant association detected for fashion and beauty retailers Usage after FDR correction (p-value: 0.000)
#
# Significant association detected for online pharmacies Usage after FDR correction (p-value: 0.000)
#
# Significant association detected for grocery delivery services Usage after FDR correction (p-value: 0.000)
#
# No significant association for specialty online stores / automobile Usage after FDR correction (p-value: 0.156)

# %% [markdown]
# # Age

# %%
df_copy2['age'].unique()
# Out:
# array([1, 0, 2, 3])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

age_map = {0: '18-25', 1: '25-35', 2: '35-45', 3: '45-55'}
df_copy2['age_label'] = df_copy2['age'].map(age_map)

# Countplot using seaborn
plt.figure(figsize=(6, 4))
sns.countplot(data=df_copy2, x='age_label', palette=['skyblue', 'lightpink', 'gray'])
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
output_dir = '/kaggle/working/age'
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# ## Age vs Binary Features

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import zipfile
import warnings

warnings.filterwarnings('ignore')

output_dir = '/kaggle/working/age/binary_features/plots'
os.makedirs(output_dir, exist_ok=True)

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')
    
df_copy2['age_label_str'] = df_copy2['age'].map({0: '18-25', 1: '25-35', 2: '35-45', 3: '45-55'})

binary_contingency_tables = []

for feature in binary_features:
    try:
        contingency_table = pd.crosstab(df_copy2['age_label_str'], df_copy2[feature])
        print(f"Contingency Table for {feature} created")

        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Feature'] = feature
        binary_contingency_tables.append(contingency_table_reset)

        plt.figure(figsize=(8, 6))
        sns.countplot(data=df_copy2, x='age_label_str', hue=feature, palette='Set2', order=['18-25', '25-35', '35-45', '45-55'])
        plt.title(f'Age vs. {feature} Usage')
        plt.xlabel('Age Group')
        plt.ylabel('Count')
        plt.legend(['Not Used', 'Used'])
        plt.tight_layout()
        filename = f"{output_dir}/age_vs_{sanitize_filename(feature)}_stacked_bar.png"
        plt.savefig(filename)
        plt.close()
        print(f"Saved plot: {filename}")
    except Exception as e:
        print(f"Failed to save plot for {feature}: {e}")
        plt.close()
        continue

if binary_contingency_tables:
    all_binary_tables_df = pd.concat(binary_contingency_tables, ignore_index=True)
    cols = ['Feature'] + [col for col in all_binary_tables_df.columns if col != 'Feature']
    all_binary_tables_df = all_binary_tables_df[cols]
    output_xlsx = '/kaggle/working/age/binary_features/binary_contingency_tables.xlsx'
    all_binary_tables_df.to_excel(output_xlsx, index=False)
    print(f"Saved binary contingency tables to: {output_xlsx}")
else:
    print("No binary contingency tables to save.")

zip_filename = '/kaggle/working/age/binary_features/plots-binary.zip'
print(f"Creating ZIP file: {zip_filename}...")

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.png'):
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, '/kaggle/working/')
                zipf.write(file_path, arcname)

print(f"ZIP file created: {zip_filename}")

print("EDA for Age vs. Binary Features completed. Plots saved as PNG files")
# Out:
# Contingency Table for have used online shopping platforms before created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_have_used_online_shopping_platforms_before_stacked_bar.png
# Contingency Table for have you made online purchases during crisis time? created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_have_you_made_online_purchases_during_crisis_time__stacked_bar.png
# Contingency Table for ali-express created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_ali-express_stacked_bar.png
# Contingency Table for daraz created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_daraz_stacked_bar.png
# Contingency Table for ebay created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_ebay_stacked_bar.png
# Contingency Table for ikman created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_ikman_stacked_bar.png
# Contingency Table for instagram stores created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_instagram_stores_stacked_bar.png
# Contingency Table for kapruka created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_kapruka_stacked_bar.png
# Contingency Table for keels created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_keels_stacked_bar.png
# Contingency Table for lassana.com created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_lassana_com_stacked_bar.png
# Contingency Table for pickme created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_pickme_stacked_bar.png
# Contingency Table for shein created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_shein_stacked_bar.png
# Contingency Table for strong.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_strong_lk_stacked_bar.png
# Contingency Table for takas created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_takas_stacked_bar.png
# Contingency Table for wishque created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_wishque_stacked_bar.png
# Contingency Table for wow created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_wow_stacked_bar.png
# Contingency Table for amazon created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_amazon_stacked_bar.png
# Contingency Table for autolanka.com created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_autolanka_com_stacked_bar.png
# Contingency Table for ikman.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_ikman_lk_stacked_bar.png
# Contingency Table for lankavechicle.com created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_lankavechicle_com_stacked_bar.png
# Contingency Table for patpat.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_patpat_lk_stacked_bar.png
# Contingency Table for pricelanka.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_pricelanka_lk_stacked_bar.png
# Contingency Table for riyasewana.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_riyasewana_lk_stacked_bar.png
# Contingency Table for specialty online stores / automobile unknown created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_specialty_online_stores___automobile_unknown_stacked_bar.png
# Contingency Table for toyota created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_toyota_stacked_bar.png
# Contingency Table for zero specialty online stores / automobile created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_zero_specialty_online_stores___automobile_stacked_bar.png
# Contingency Table for ceymed.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_ceymed_lk_stacked_bar.png
# Contingency Table for epharma.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_epharma_lk_stacked_bar.png
# Contingency Table for healthgurd.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_healthgurd_lk_stacked_bar.png
# Contingency Table for healthnet.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_healthnet_lk_stacked_bar.png
# Contingency Table for nearby pharmacy created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_nearby_pharmacy_stacked_bar.png
# Contingency Table for no online pharmacies created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_no_online_pharmacies_stacked_bar.png
# Contingency Table for online pharmacy unknown created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_online_pharmacy_unknown_stacked_bar.png
# Contingency Table for onlinepharmacy.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_onlinepharmacy_lk_stacked_bar.png
# Contingency Table for union chemist created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_union_chemist_stacked_bar.png
# Contingency Table for amanthe created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_amanthe_stacked_bar.png
# Contingency Table for carlo clothing created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_carlo_clothing_stacked_bar.png
# Contingency Table for carnage, created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_carnage__stacked_bar.png
# Contingency Table for chenara dodge created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_chenara_dodge_stacked_bar.png
# Contingency Table for dsi created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_dsi_stacked_bar.png
# Contingency Table for fashionbug.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_fashionbug_lk_stacked_bar.png
# Contingency Table for gflock created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_gflock_stacked_bar.png
# Contingency Table for kapruka.com/fashion created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_kapruka_com_fashion_stacked_bar.png
# Contingency Table for kelly felder created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_kelly_felder_stacked_bar.png
# Contingency Table for kynd fashion created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_kynd_fashion_stacked_bar.png
# Contingency Table for midnightdivas.com created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_midnightdivas_com_stacked_bar.png
# Contingency Table for mimosa created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_mimosa_stacked_bar.png
# Contingency Table for moods created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_moods_stacked_bar.png
# Contingency Table for moose created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_moose_stacked_bar.png
# Contingency Table for nills created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_nills_stacked_bar.png
# Contingency Table for no fashion and beauty retailers created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_no_fashion_and_beauty_retailers_stacked_bar.png
# Contingency Table for nolimit.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_nolimit_lk_stacked_bar.png
# Contingency Table for noorareed.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_noorareed_lk_stacked_bar.png
# Contingency Table for odel.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_odel_lk_stacked_bar.png
# Contingency Table for s&s created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_s_s_stacked_bar.png
# Contingency Table for spring and summer created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_spring_and_summer_stacked_bar.png
# Contingency Table for tharshana and insta shops created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_tharshana_and_insta_shops_stacked_bar.png
# Contingency Table for thilakawardana.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_thilakawardana_lk_stacked_bar.png
# Contingency Table for unknown fashion and beauty retailers created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_unknown_fashion_and_beauty_retailers_stacked_bar.png
# Contingency Table for zigzag.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_zigzag_lk_stacked_bar.png
# Contingency Table for arpico.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_arpico_lk_stacked_bar.png
# Contingency Table for cargillsonline.com created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_cargillsonline_com_stacked_bar.png
# Contingency Table for cinnamonhotel.com created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_cinnamonhotel_com_stacked_bar.png
# Contingency Table for glomark.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_glomark_lk_stacked_bar.png
# Contingency Table for grocery delivery services not used created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_grocery_delivery_services_not_used_stacked_bar.png
# Contingency Table for keellssuper.lk created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_keellssuper_lk_stacked_bar.png
# Contingency Table for pickmefoods.com created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_pickmefoods_com_stacked_bar.png
# Contingency Table for ubereats.com created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_ubereats_com_stacked_bar.png
# Contingency Table for unknown grocery delivery services created
# Saved plot: /kaggle/working/age/binary_features/plots/age_vs_unknown_grocery_delivery_services_stacked_bar.png
# Saved binary contingency tables to: /kaggle/working/age/binary_features/binary_contingency_tables.xlsx
# Creating ZIP file: /kaggle/working/age/binary_features/plots-binary.zip...
# ZIP file created: /kaggle/working/age/binary_features/plots-binary.zip
# EDA for Age vs. Binary Features completed. Plots saved as PNG files

# %% [markdown]
# ## Age vs Platform Groups

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import zipfile
import warnings

warnings.filterwarnings('ignore')

output_dir = '/kaggle/working/age/platform_groups/plots'
os.makedirs(output_dir, exist_ok=True)

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')

df_copy2['age_label_str'] = df_copy2['age'].map({0: '18-25', 1: '25-35', 2: '35-45', 3: '45-55'})

# Define platform groups (as provided earlier)
platform_groups = [
    'general e-commerce platforms', 'specialty online stores / automobile', 'online pharmacies', 
    'fashion and beauty retailers', 'grocery delivery services'
]

not_used_values = {
    'general e-commerce platforms': None,  # No explicit "not used" value
    'specialty online stores / automobile': 'zero specialty online stores / automobile',
    'online pharmacies': 'no online pharmacies',
    'fashion and beauty retailers': 'no fashion and beauty retailers',
    'grocery delivery services': 'grocery delivery services not used'
}

unknown_values = {
    'general e-commerce platforms': None,  # No explicit "unknown" value
    'specialty online stores / automobile': 'specialty online stores / automobile unknown',
    'online pharmacies': 'online pharmacy unknown',
    'fashion and beauty retailers': 'unknown fashion and beauty retailers',
    'grocery delivery services': 'unknown grocery delivery services'
}

for group in platform_groups:
    df_copy2[f'{group}_status'] = df_copy2[group].apply(
        lambda x: 'unknown' if pd.isna(x) or (group in unknown_values and x == unknown_values[group])
        else 'not used' if group in not_used_values and x == not_used_values[group]
        else 'used'
    )

platform_group_status = [f'{group}_status' for group in platform_groups]

status_order = ['not used', 'used', 'unknown']

platform_contingency_tables = []

for group_status in platform_group_status:
    try:
        contingency_table = pd.crosstab(df_copy2['age_label_str'], df_copy2[group_status])
        #print(f"Contingency Table for {group_status} created")

        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Platform Group'] = group_status
        platform_contingency_tables.append(contingency_table_reset)

        plt.figure(figsize=(8, 6))
        sns.countplot(
            data=df_copy2, 
            x='age_label_str', 
            hue=group_status, 
            hue_order=status_order, 
            palette='Set2', 
            order=['18-25', '25-35', '45-55']
        )
        plt.title(f'Age vs. {group_status.replace("_status", "")} Usage')
        plt.xlabel('Age Group')
        plt.ylabel('Count')
        plt.legend(title='Usage Status', labels=['Not Used', 'Used', 'Unknown'])
        plt.tight_layout()
        filename = f"{output_dir}/age_vs_{sanitize_filename(group_status)}_stacked_bar.png"
        plt.savefig(filename)
        plt.close()
        print(f"Saved plot: {filename}")
    except Exception as e:
        print(f"Failed to save plot for {group_status}: {e}")
        plt.close()
        continue

if platform_contingency_tables:
    all_platform_tables_df = pd.concat(platform_contingency_tables, ignore_index=True)
    cols = ['Platform Group'] + [col for col in all_platform_tables_df.columns if col != 'Platform Group']
    all_platform_tables_df = all_platform_tables_df[cols]
    output_xlsx = '/kaggle/working/age/platform_groups/platform_contingency_tables.xlsx'
    all_platform_tables_df.to_excel(output_xlsx, index=False)
    print(f"Saved platform group contingency tables to: {output_xlsx}")
else:
    print("No platform group contingency tables to save.")

zip_filename = '/kaggle/working/age/platform_groups/plots_platform_groups.zip'
print(f"Creating ZIP file: {zip_filename}...")

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.png'):
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, '/kaggle/working/')
                zipf.write(file_path, arcname)

print(f"ZIP file created: {zip_filename}")

print("EDA for Age vs. Platform Groups completed. Plots saved as PNG files")
# Out:
# Saved plot: /kaggle/working/age/platform_groups/plots/age_vs_general_e-commerce_platforms_status_stacked_bar.png
# Saved plot: /kaggle/working/age/platform_groups/plots/age_vs_specialty_online_stores___automobile_status_stacked_bar.png
# Saved plot: /kaggle/working/age/platform_groups/plots/age_vs_online_pharmacies_status_stacked_bar.png
# Saved plot: /kaggle/working/age/platform_groups/plots/age_vs_fashion_and_beauty_retailers_status_stacked_bar.png
# Saved plot: /kaggle/working/age/platform_groups/plots/age_vs_grocery_delivery_services_status_stacked_bar.png
# Saved platform group contingency tables to: /kaggle/working/age/platform_groups/platform_contingency_tables.xlsx
# Creating ZIP file: /kaggle/working/age/platform_groups/plots_platform_groups.zip...
# ZIP file created: /kaggle/working/age/platform_groups/plots_platform_groups.zip
# EDA for Age vs. Platform Groups completed. Plots saved as PNG files

# %% [markdown]
# ## Age vs Other Features

# %%
import pandas as pd
from scipy.stats import spearmanr, kendalltau
import os

output_dir = '/kaggle/working/age/other_features'
os.makedirs(output_dir, exist_ok=True)

results = []
insights_list = []

# Compute Spearman’s and Kendall’s correlations for each feature
for feature in other_features:
    data = df_copy2[['age', feature]]
    
    # Spearman’s correlation
    spearman_corr, spearman_p = spearmanr(data['age'], data[feature])
    
    # Kendall’s correlation
    kendall_corr, kendall_p = kendalltau(data['age'], data[feature])

    insight = ""
    if spearman_p < 0.05 and kendall_p < 0.05:
        if spearman_corr > 0:
            insight = f"Significant positive correlation: As age increases, agreement on '{feature}' increases."
        elif spearman_corr < 0:
            insight = f"Significant negative correlation: As age increases, agreement on '{feature}' decreases."
        else:
            insight = f"Significant but no clear direction for '{feature}' (correlation near zero)."
    else:
        insight = f"No significant correlation between age and '{feature}' (p ≥ 0.05)."

    insights_list.append(insight)
    
    # Store results
    results.append({
        'Feature': feature,
        'Spearman Correlation': spearman_corr,
        'Spearman P-Value': spearman_p,
        'Kendall Correlation': kendall_corr,
        'Kendall P-Value': kendall_p,
    })

correlation_results = pd.DataFrame(results)

print("=== Correlation Analysis for Age vs Other Features ===")
print(correlation_results)

print("\n============== Significance ====================")
for insight in insights_list:
    print(insight)

output_xlsx = f"{output_dir}/age_vs_other_features_correlations.xlsx"
correlation_results.to_excel(output_xlsx, index=False)
# Out:
# === Correlation Analysis for Age vs Other Features ===
#                                               Feature  Spearman Correlation  \
# 0   it is easy to navigate through the online plat...             -0.069477
# 1   the online platform provides clear and intuiti...             -0.044506
# 2   it was easy for me to learn how to use the onl...             -0.237294
# 3   i quickly became proficient in using the onlin...             -0.165222
# 4   the instructions provided on the online platfo...             -0.117798
# 5   i can easily follow the instructions given on ...             -0.105176
# 6   the online platform responds quickly to my act...              0.080075
# 7   i don't experience delays or long waiting time...              0.089908
# 8   the online platform effectively handles errors...              0.009092
# 9   i rarely encounter errors or issues when using...              0.059144
# 10  the online platform offers a wide range of pro...             -0.053443
# 11  i can find the products or services i need on ...             -0.031252
# 12  using the online platform for making purchases...             -0.227554
# 13  the online platform makes it easy to search fo...             -0.137988
# 14  the online platform offers competitive prices,...              0.003846
# 15  i perceive that using the online platform for ...             -0.083744
# 16  the online platform provides detailed and accu...              0.023057
# 17  i can easily access user reviews, ratings, and...             -0.136449
# 18  the online platform tailors recommendations, s...             -0.035029
# 19  i feel that the online platform understands my...             -0.032227
# 20  the online platform takes appropriate measures...             -0.003013
# 21  i trust that my personal information will be h...              0.077124
# 22  the online platform provides secure payment me...             -0.101090
# 23  i trust that my payment details are handled se...             -0.088301
# 24  the online platform provides clear and easily ...              0.022422
# 25  i feel confident in the online platform's tran...             -0.019397
# 26  i am influenced by recommendations and opinion...             -0.005586
# 27  i consider the experiences and suggestions sha...             -0.176106
# 28  during a crisis, social media platforms, influ...             -0.083314
# 29  i am likely to make online purchases during a ...             -0.049912
# 30  i consider online reviews and ratings when mak...             -0.175130
# 31  positive reviews and high ratings increase my ...             -0.185950
# 32  observing others making online purchases durin...             -0.124630
# 33  i am more likely to make online purchases duri...             -0.073619
# 34  social norms and expectations regarding online...             -0.050248
# 35  i feel pressure to make online purchases durin...              0.067533
# 36  i am willing to share my own online shopping e...             -0.171037
# 37  sharing information about my online purchases ...             -0.124623
# 38  overall, i have a positive attitude toward onl...             -0.075765
# 39  i believe that online shopping is a practical ...              0.013246
# 40  i am concerned about the security of my person...             -0.017837
# 41  i am cautious about the reliability and authen...             -0.023551
# 42  overall, i am satisfied with online purchase d...              0.002790
# 43  i have changed my online shopping behavior dur...             -0.059513
# 44  it was convenient for me to do online shopping...             -0.080995
# 45  i believe that online shopping during a crisis...             -0.096624
#
#     Spearman P-Value  Kendall Correlation  Kendall P-Value
# 0       4.565128e-02            -0.063798     4.702933e-02
# 1       2.007731e-01            -0.041349     2.007720e-01
# 2       4.617815e-12            -0.222853     4.048127e-12
# 3       1.753189e-06            -0.155300     1.412930e-06
# 4       6.829395e-04            -0.111891     6.370425e-04
# 5       2.443224e-03            -0.099332     2.237861e-03
# 6       2.120102e-02             0.073732     2.194263e-02
# 7       9.640909e-03             0.083371     1.018415e-02
# 8       7.939101e-01             0.006668     8.352541e-01
# 9       8.898141e-02             0.052014     1.035421e-01
# 10      1.243900e-01            -0.050291     1.180848e-01
# 11      3.691062e-01            -0.029970     3.559870e-01
# 12      3.470753e-11            -0.209678     4.644363e-11
# 13      6.786063e-05            -0.126537     7.494710e-05
# 14      9.120060e-01             0.003686     9.091822e-01
# 15      1.593807e-02            -0.078279     1.443450e-02
# 16      5.076244e-01             0.022214     4.947929e-01
# 17      8.188713e-05            -0.123990     1.000412e-04
# 18      3.140608e-01            -0.033202     3.080426e-01
# 19      3.543633e-01            -0.030597     3.465729e-01
# 20      9.310186e-01            -0.003308     9.192896e-01
# 21      2.647272e-02             0.070982     2.895320e-02
# 22      3.592109e-03            -0.095806     3.517075e-03
# 23      1.102250e-02            -0.083261     1.054107e-02
# 24      5.193872e-01             0.020501     5.289007e-01
# 25      5.772765e-01            -0.018893     5.631315e-01
# 26      8.724964e-01            -0.004593     8.853042e-01
# 27      3.401992e-07            -0.164911     3.517985e-07
# 28      1.648914e-02            -0.076593     1.545886e-02
# 29      1.513046e-01            -0.046587     1.443576e-01
# 30      3.957332e-07            -0.163607     3.164367e-07
# 31      7.057728e-08            -0.171710     7.227778e-08
# 32      3.246143e-04            -0.117159     2.904613e-04
# 33      3.416896e-02            -0.070509     2.808915e-02
# 34      1.485700e-01            -0.048129     1.395271e-01
# 35      5.207188e-02             0.061355     5.406144e-02
# 36      7.395686e-07            -0.159432     8.703663e-07
# 37      3.248405e-04            -0.116932     3.225354e-04
# 38      2.925820e-02            -0.069691     2.881468e-02
# 39      7.035061e-01             0.012442     7.000764e-01
# 40      6.082806e-01            -0.016773     5.998486e-01
# 41      4.985653e-01            -0.021503     5.006379e-01
# 42      9.361076e-01             0.002784     9.305270e-01
# 43      8.700264e-02            -0.054972     8.930634e-02
# 44      1.975710e-02            -0.075032     2.001326e-02
# 45      5.391498e-03            -0.089476     5.419363e-03
#
# ============== Significance ====================
# Significant negative correlation: As age increases, agreement on 'it is easy to navigate through the online platform to find the products or services i need' decreases.
# No significant correlation between age and 'the online platform provides clear and intuitive navigation options' (p ≥ 0.05).
# Significant negative correlation: As age increases, agreement on 'it was easy for me to learn how to use the online platform for making online purchases' decreases.
# Significant negative correlation: As age increases, agreement on 'i quickly became proficient in using the online platform for making online purchases during a crisis' decreases.
# Significant negative correlation: As age increases, agreement on 'the instructions provided on the online platform are clear and easy to understand' decreases.
# Significant negative correlation: As age increases, agreement on 'i can easily follow the instructions given on the online platform for making online purchases' decreases.
# Significant positive correlation: As age increases, agreement on 'the online platform responds quickly to my actions, such as loading pages and processing transactions.' increases.
# Significant positive correlation: As age increases, agreement on 'i don't experience delays or long waiting times when using the online platform for making online purchases during a crisis' increases.
# No significant correlation between age and 'the online platform effectively handles errors or mistakes, such as providing clear error messages and easy recovery options' (p ≥ 0.05).
# No significant correlation between age and 'i rarely encounter errors or issues when using the online platform for making online purchases during a crisis' (p ≥ 0.05).
# No significant correlation between age and 'the online platform offers a wide range of products and services that meet my needs during a crisis' (p ≥ 0.05).
# No significant correlation between age and 'i can find the products or services i need on the online platform during a crisis' (p ≥ 0.05).
# Significant negative correlation: As age increases, agreement on 'using the online platform for making purchases during a crisis is convenient and saves time' decreases.
# Significant negative correlation: As age increases, agreement on 'the online platform makes it easy to search for products and complete transactions during a crisis' decreases.
# No significant correlation between age and 'the online platform offers competitive prices, discounts, or cost-saving benefits during a crisis' (p ≥ 0.05).
# Significant negative correlation: As age increases, agreement on 'i perceive that using the online platform for making purchases during a crisis can help me save money' decreases.
# No significant correlation between age and 'the online platform provides detailed and accurate product information during a crisis' (p ≥ 0.05).
# Significant negative correlation: As age increases, agreement on 'i can easily access user reviews, ratings, and other relevant information to support my purchase decisions' decreases.
# No significant correlation between age and 'the online platform tailors recommendations, suggestions, or personalized offers based on my preferences' (p ≥ 0.05).
# No significant correlation between age and 'i feel that the online platform understands my needs and preferences during a crisis' (p ≥ 0.05).
# No significant correlation between age and 'the online platform takes appropriate measures to protect my privacy' (p ≥ 0.05).
# Significant positive correlation: As age increases, agreement on 'i trust that my personal information will be handled securely by the online platform' increases.
# Significant negative correlation: As age increases, agreement on 'the online platform provides secure payment methods to protect against fraudulent activities during a crisis' decreases.
# Significant negative correlation: As age increases, agreement on 'i trust that my payment details are handled securely by the online platform' decreases.
# No significant correlation between age and 'the online platform provides clear and easily accessible policies regarding data handling, privacy, and security' (p ≥ 0.05).
# No significant correlation between age and 'i feel confident in the online platform's transparency regarding its data protection practices' (p ≥ 0.05).
# No significant correlation between age and 'i am influenced by recommendations and opinions from family and friends when making online purchases during a crisis' (p ≥ 0.05).
# Significant negative correlation: As age increases, agreement on 'i consider the experiences and suggestions shared by people i know before making online purchases during a crisis' decreases.
# Significant negative correlation: As age increases, agreement on 'during a crisis, social media platforms, influencers, and online communities influence my online purchase decisions' decreases.
# No significant correlation between age and 'i am likely to make online purchases during a crisis based on what i see or learn from social media platforms' (p ≥ 0.05).
# Significant negative correlation: As age increases, agreement on 'i consider online reviews and ratings when making purchasing decisions during a crisis' decreases.
# Significant negative correlation: As age increases, agreement on 'positive reviews and high ratings increase my confidence in making online purchases during a crisis' decreases.
# Significant negative correlation: As age increases, agreement on 'observing others making online purchases during a crisis influences my own intention to make similar purchases' decreases.
# Significant negative correlation: As age increases, agreement on 'i am more likely to make online purchases during a crisis if i see others doing the same' decreases.
# No significant correlation between age and 'social norms and expectations regarding online shopping during a crisis influence my own intention to make online purchases' (p ≥ 0.05).
# No significant correlation between age and 'i feel pressure to make online purchases during a crisis due to the expectations of others' (p ≥ 0.05).
# Significant negative correlation: As age increases, agreement on 'i am willing to share my own online shopping experiences, recommendations, or opinions with others during a crisis' decreases.
# Significant negative correlation: As age increases, agreement on 'sharing information about my online purchases during a crisis is important for influencing others' purchase decisions' decreases.
# Significant negative correlation: As age increases, agreement on 'overall, i have a positive attitude toward online shopping during a crisis' decreases.
# No significant correlation between age and 'i believe that online shopping is a practical and efficient way to make purchases during a crisis' (p ≥ 0.05).
# No significant correlation between age and 'i am concerned about the security of my personal and financial information when shopping online during a crisis' (p ≥ 0.05).
# No significant correlation between age and 'i am cautious about the reliability and authenticity of products or services offered by online platforms during a crisis' (p ≥ 0.05).
# No significant correlation between age and 'overall, i am satisfied with online purchase during a crisis?' (p ≥ 0.05).
# No significant correlation between age and 'i have changed my online shopping behavior during a crisis compared to non-crisis periods?' (p ≥ 0.05).
# Significant negative correlation: As age increases, agreement on 'it was convenient for me to do online shopping during a crisis compared to traditional in-store shopping' decreases.
# Significant negative correlation: As age increases, agreement on 'i believe that online shopping during a crisis offers better value for money compared to traditional shopping methods' decreases.

# %% [markdown]
# # Highest Level of Education

# %%
df_copy2['highest level of education'].unique()
# Out:
# array([3, 4, 2, 0, 1, 5])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

education_map = {
    0: 'Grade 8 pass', 1: 'High school', 2: 'Diploma / Certificate Course',
    3: "Bachelor's Degree", 4: "Master's Degree or higher", 5: "Postgraduate Diploma"
}
df_copy2['education_label'] = df_copy2['highest level of education'].map(education_map)

# Countplot using seaborn
plt.figure(figsize=(8, 6))
sns.countplot(data=df_copy2, x='education_label', palette=['skyblue', 'lightpink', 'gray'])
plt.title('Level of Education Distribution')
plt.xlabel('Level of Education')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Highest Level of Education vs Binary Features

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import zipfile
import warnings
from scipy.stats import chi2_contingency
import numpy as np

warnings.filterwarnings('ignore')

output_dir = '/kaggle/working/education/binary_features/plots'
os.makedirs(output_dir, exist_ok=True)

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')

df_copy2['education_label_str'] = df_copy2['highest level of education'].map({
    0: 'Grade 8 pass', 1: 'High school', 2: 'Diploma / Certificate Course',
    3: "Bachelor's Degree", 4: "Master's Degree or higher", 5: "Postgraduate Diploma"
})

education_order = ['Grade 8 pass', 'High school', 'Diploma / Certificate Course', 
                   "Bachelor's Degree", "Master's Degree or higher", "Postgraduate Diploma"]

binary_contingency_tables = []

for feature in binary_features:
    try:
        contingency_table = pd.crosstab(df_copy2['education_label_str'], df_copy2[feature])

        # Reorder the contingency table rows according to education_order
        contingency_table = contingency_table.reindex(education_order)

        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Feature'] = feature
        binary_contingency_tables.append(contingency_table_reset)

        plt.figure(figsize=(10, 6))
        sns.countplot(data=df_copy2, x='education_label_str', hue=feature, palette='Set2', order=education_order)
        plt.title(f'Education vs. {feature} Usage')
        plt.xlabel('Education Level')
        plt.ylabel('Count')
        plt.legend(['Not Used', 'Used'])
        plt.xticks(rotation=45)
        plt.tight_layout()
        filename = f"{output_dir}/education_vs_{sanitize_filename(feature)}_stacked_bar.png"
        plt.savefig(filename)
        plt.close()
        print(f"Saved plot: {filename}")
    except Exception as e:
        print(f"Failed to save plot for {feature}: {e}")
        plt.close()
        continue

if binary_contingency_tables:
    all_binary_tables_df = pd.concat(binary_contingency_tables, ignore_index=True)
    cols = ['Feature'] + [col for col in all_binary_tables_df.columns if col not in ['Feature']]
    all_binary_tables_df = all_binary_tables_df[cols]
    output_xlsx = '/kaggle/working/education/binary_features/binary_contingency_tables.xlsx'
    all_binary_tables_df.to_excel(output_xlsx, index=False)
    print(f"Saved binary contingency tables to: {output_xlsx}")
else:
    print("No binary contingency tables to save.")

zip_filename = '/kaggle/working/education/binary_features/plots-association.zip'
print(f"Creating ZIP file: {zip_filename}...")

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.png'):
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, '/kaggle/working/')
                zipf.write(file_path, arcname)

print(f"ZIP file created: {zip_filename}")

print("EDA for Education vs. Binary Features completed. Plots saved as PNG files")
# Out:
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_have_used_online_shopping_platforms_before_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_have_you_made_online_purchases_during_crisis_time__stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_ali-express_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_daraz_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_ebay_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_ikman_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_instagram_stores_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_kapruka_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_keels_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_lassana_com_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_pickme_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_shein_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_strong_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_takas_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_wishque_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_wow_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_amazon_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_autolanka_com_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_ikman_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_lankavechicle_com_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_patpat_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_pricelanka_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_riyasewana_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_specialty_online_stores___automobile_unknown_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_toyota_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_zero_specialty_online_stores___automobile_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_ceymed_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_epharma_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_healthgurd_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_healthnet_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_nearby_pharmacy_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_no_online_pharmacies_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_online_pharmacy_unknown_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_onlinepharmacy_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_union_chemist_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_amanthe_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_carlo_clothing_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_carnage__stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_chenara_dodge_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_dsi_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_fashionbug_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_gflock_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_kapruka_com_fashion_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_kelly_felder_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_kynd_fashion_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_midnightdivas_com_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_mimosa_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_moods_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_moose_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_nills_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_no_fashion_and_beauty_retailers_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_nolimit_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_noorareed_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_odel_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_s_s_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_spring_and_summer_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_tharshana_and_insta_shops_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_thilakawardana_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_unknown_fashion_and_beauty_retailers_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_zigzag_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_arpico_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_cargillsonline_com_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_cinnamonhotel_com_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_glomark_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_grocery_delivery_services_not_used_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_keellssuper_lk_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_pickmefoods_com_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_ubereats_com_stacked_bar.png
# Saved plot: /kaggle/working/education/binary_features/plots/education_vs_unknown_grocery_delivery_services_stacked_bar.png
# Saved binary contingency tables to: /kaggle/working/education/binary_features/binary_contingency_tables.xlsx
# Creating ZIP file: /kaggle/working/education/binary_features/plots-association.zip...
# ZIP file created: /kaggle/working/education/binary_features/plots-association.zip
# EDA for Education vs. Binary Features completed. Plots saved as PNG files

# %% [markdown]
# ## Highest Level of Education vs Platform Groups

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import zipfile
import warnings
from scipy.stats import chi2_contingency
import numpy as np

warnings.filterwarnings('ignore')

output_dir = '/kaggle/working/education/platform_groups/plots'
os.makedirs(output_dir, exist_ok=True)

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')

df_copy2['education_label_str'] = df_copy2['highest level of education'].map({
    0: 'Grade 8 pass', 1: 'High school', 2: 'Diploma / Certificate Course',
    3: "Bachelor's Degree", 4: "Master's Degree or higher", 5: "Postgraduate Diploma"
})

education_order = ['Grade 8 pass', 'High school', 'Diploma / Certificate Course', 
                   "Bachelor's Degree", "Master's Degree or higher", "Postgraduate Diploma"]

not_used_values = {
    'general e-commerce platforms': None,
    'specialty online stores / automobile': 'zero specialty online stores / automobile',
    'online pharmacies': 'no online pharmacies',
    'fashion and beauty retailers': 'no fashion and beauty retailers',
    'grocery delivery services': 'grocery delivery services not used'
}

unknown_values = {
    'general e-commerce platforms': None,
    'specialty online stores / automobile': 'specialty online stores / automobile unknown',
    'online pharmacies': 'online pharmacy unknown',
    'fashion and beauty retailers': 'unknown fashion and beauty retailers',
    'grocery delivery services': 'unknown grocery delivery services'
}

for group in platform_groups:
    df_copy2[f'{group}_status'] = df_copy2[group].apply(
        lambda x: 'unknown' if pd.isna(x) or (group in unknown_values and x == unknown_values[group])
        else 'not used' if group in not_used_values and x == not_used_values[group]
        else 'used'
    )

platform_group_status = [f'{group}_status' for group in platform_groups]

status_order = ['not used', 'used', 'unknown']

platform_contingency_tables = []

for group_status in platform_group_status:
    try:
        contingency_table = pd.crosstab(df_copy2['education_label_str'], df_copy2[group_status])
        print(f"Contingency Table for {group_status} created")

        contingency_table = contingency_table.reindex(education_order)

        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Platform Group'] = group_status

        platform_contingency_tables.append(contingency_table_reset)

        plt.figure(figsize=(10, 6))
        sns.countplot(
            data=df_copy2, 
            x='education_label_str', 
            hue=group_status, 
            hue_order=status_order, 
            palette='Set2', 
            order=education_order
        )
        plt.title(f'Education vs. {group_status.replace("_status", "")} Usage')
        plt.xlabel('Education Level')
        plt.ylabel('Count')
        plt.legend(title='Usage Status', labels=['Not Used', 'Used', 'Unknown'])
        plt.xticks(rotation=45)
        plt.tight_layout()
        filename = f"{output_dir}/education_vs_{sanitize_filename(group_status)}_stacked_bar.png"
        plt.savefig(filename)
        plt.close()
        print(f"Saved plot: {filename}")
    except Exception as e:
        print(f"Failed to save plot for {group_status}: {e}")
        plt.close()
        continue

if platform_contingency_tables:
    all_platform_tables_df = pd.concat(platform_contingency_tables, ignore_index=True)
    cols = ['Platform Group'] + [col for col in all_platform_tables_df.columns if col not in ['Platform Group']]
    all_platform_tables_df = all_platform_tables_df[cols]
    output_xlsx = '/kaggle/working/education/platform_groups/platform_contingency_tables.xlsx'
    all_platform_tables_df.to_excel(output_xlsx, index=False)
    print(f"Saved platform group contingency tables to: {output_xlsx}")
else:
    print("No platform group contingency tables to save.")

# Create a ZIP file containing all the plots
zip_filename = '/kaggle/working/education/platform_groups/plots_grouped_platform.zip'
print(f"Creating ZIP file: {zip_filename}...")

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.png'):
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, '/kaggle/working/')
                zipf.write(file_path, arcname)

print(f"ZIP file created: {zip_filename}")

print("EDA for Education vs. Platform Groups completed. Plots saved as PNG files")
# Out:
# Contingency Table for general e-commerce platforms_status created
# Saved plot: /kaggle/working/education/platform_groups/plots/education_vs_general_e-commerce_platforms_status_stacked_bar.png
# Contingency Table for specialty online stores / automobile_status created
# Saved plot: /kaggle/working/education/platform_groups/plots/education_vs_specialty_online_stores___automobile_status_stacked_bar.png
# Contingency Table for online pharmacies_status created
# Saved plot: /kaggle/working/education/platform_groups/plots/education_vs_online_pharmacies_status_stacked_bar.png
# Contingency Table for fashion and beauty retailers_status created
# Saved plot: /kaggle/working/education/platform_groups/plots/education_vs_fashion_and_beauty_retailers_status_stacked_bar.png
# Contingency Table for grocery delivery services_status created
# Saved plot: /kaggle/working/education/platform_groups/plots/education_vs_grocery_delivery_services_status_stacked_bar.png
# Saved platform group contingency tables to: /kaggle/working/education/platform_groups/platform_contingency_tables.xlsx
# Creating ZIP file: /kaggle/working/education/platform_groups/plots_grouped_platform.zip...
# ZIP file created: /kaggle/working/education/platform_groups/plots_grouped_platform.zip
# EDA for Education vs. Platform Groups completed. Plots saved as PNG files

# %% [markdown]
# ## Highest Level of Education vs Other Features

# %%
import pandas as pd
from scipy.stats import spearmanr, kendalltau
import os

output_dir = '/kaggle/working/education/other_features'
os.makedirs(output_dir, exist_ok=True)

results = []
insights_list = []

# Compute Spearman’s and Kendall’s correlations for each feature
for feature in other_features:
    data = df_copy2[['highest level of education', feature]]
    
    # Spearman’s correlation
    spearman_corr, spearman_p = spearmanr(data['highest level of education'], data[feature])
    
    # Kendall’s correlation
    kendall_corr, kendall_p = kendalltau(data['highest level of education'], data[feature])

    insight = ""
    if spearman_p < 0.05 and kendall_p < 0.05:
        if spearman_corr > 0:
            insight = f"Significant positive correlation: As the level of education increases, agreement on '{feature}' increases."
        elif spearman_corr < 0:
            insight = f"Significant negative correlation: As the level of education increases, agreement on '{feature}' decreases."
        else:
            insight = f"Significant but no clear direction for '{feature}' (correlation near zero)."
    else:
        insight = f"No significant correlation between the level of education and '{feature}' (p ≥ 0.05)."

    insights_list.append(insight)
    
    results.append({
        'Feature': feature,
        'Spearman Correlation': spearman_corr,
        'Spearman P-Value': spearman_p,
        'Kendall Correlation': kendall_corr,
        'Kendall P-Value': kendall_p
    })
    
correlation_results = pd.DataFrame(results)

print("=== Correlation Analysis for Highest Level of Education vs Other Features ===")
print(correlation_results)

print("\n============== Significance ====================")
for insight in insights_list:
    print(insight)

output_xlsx = f"{output_dir}/education_vs_other_features_correlations.xlsx"
correlation_results.to_excel(output_xlsx, index=False)
# Out:
# === Correlation Analysis for Highest Level of Education vs Other Features ===
#                                               Feature  Spearman Correlation  \
# 0   it is easy to navigate through the online plat...              0.091993
# 1   the online platform provides clear and intuiti...              0.072125
# 2   it was easy for me to learn how to use the onl...              0.006245
# 3   i quickly became proficient in using the onlin...             -0.026718
# 4   the instructions provided on the online platfo...              0.026814
# 5   i can easily follow the instructions given on ...              0.066487
# 6   the online platform responds quickly to my act...              0.094961
# 7   i don't experience delays or long waiting time...              0.150859
# 8   the online platform effectively handles errors...              0.129603
# 9   i rarely encounter errors or issues when using...              0.192718
# 10  the online platform offers a wide range of pro...              0.101552
# 11  i can find the products or services i need on ...              0.091367
# 12  using the online platform for making purchases...             -0.100139
# 13  the online platform makes it easy to search fo...              0.006378
# 14  the online platform offers competitive prices,...             -0.038574
# 15  i perceive that using the online platform for ...             -0.109002
# 16  the online platform provides detailed and accu...              0.042791
# 17  i can easily access user reviews, ratings, and...             -0.000521
# 18  the online platform tailors recommendations, s...              0.028947
# 19  i feel that the online platform understands my...              0.072456
# 20  the online platform takes appropriate measures...              0.043156
# 21  i trust that my personal information will be h...              0.080290
# 22  the online platform provides secure payment me...             -0.029456
# 23  i trust that my payment details are handled se...             -0.026490
# 24  the online platform provides clear and easily ...              0.023632
# 25  i feel confident in the online platform's tran...              0.040110
# 26  i am influenced by recommendations and opinion...             -0.057579
# 27  i consider the experiences and suggestions sha...             -0.031908
# 28  during a crisis, social media platforms, influ...             -0.059000
# 29  i am likely to make online purchases during a ...             -0.062393
# 30  i consider online reviews and ratings when mak...              0.027390
# 31  positive reviews and high ratings increase my ...             -0.008295
# 32  observing others making online purchases durin...             -0.114022
# 33  i am more likely to make online purchases duri...             -0.073560
# 34  social norms and expectations regarding online...             -0.036283
# 35  i feel pressure to make online purchases durin...             -0.017210
# 36  i am willing to share my own online shopping e...             -0.054883
# 37  sharing information about my online purchases ...             -0.024084
# 38  overall, i have a positive attitude toward onl...              0.067321
# 39  i believe that online shopping is a practical ...              0.006522
# 40  i am concerned about the security of my person...              0.067208
# 41  i am cautious about the reliability and authen...              0.140056
# 42  overall, i am satisfied with online purchase d...              0.167830
# 43  i have changed my online shopping behavior dur...             -0.010324
# 44  it was convenient for me to do online shopping...              0.011959
# 45  i believe that online shopping during a crisis...              0.082176
#
#     Spearman P-Value  Kendall Correlation  Kendall P-Value
# 0       8.079981e-03             0.082710     8.117370e-03
# 1       3.799112e-02             0.065468     3.729212e-02
# 2       8.576035e-01             0.006605     8.326173e-01
# 3       4.426201e-01            -0.023502     4.530018e-01
# 4       4.409840e-01             0.024899     4.345822e-01
# 5       5.582657e-02             0.061002     5.361120e-02
# 6       6.246503e-03             0.086311     5.821247e-03
# 7       1.304338e-05             0.139096     1.046013e-05
# 8       1.844093e-04             0.117975     1.551130e-04
# 9       2.276525e-08             0.174664     1.906509e-08
# 10      3.441045e-03             0.092284     3.193447e-03
# 11      8.522993e-03             0.083663     8.068462e-03
# 12      3.921489e-03            -0.089653     3.811613e-03
# 13      8.546076e-01             0.005707     8.543148e-01
# 14      2.675565e-01            -0.034688     2.697887e-01
# 15      1.682785e-03            -0.098200     1.604637e-03
# 16      2.186917e-01             0.039518     2.117963e-01
# 17      9.880458e-01            -0.000621     9.840146e-01
# 18      4.054917e-01             0.027009     3.939214e-01
# 19      3.711455e-02             0.066904     3.434475e-02
# 20      2.147854e-01             0.040060     2.071595e-01
# 21      2.085558e-02             0.074021     1.919761e-02
# 22      3.972669e-01            -0.027164     3.949060e-01
# 23      4.465259e-01            -0.024325     4.423677e-01
# 24      4.970844e-01             0.021498     4.972181e-01
# 25      2.489599e-01             0.036896     2.456679e-01
# 26      9.778334e-02            -0.051349     9.734287e-02
# 27      3.591445e-01            -0.029533     3.483533e-01
# 28      8.976716e-02            -0.052296     8.917122e-02
# 29      7.275090e-02            -0.056068     7.088094e-02
# 30      4.312216e-01             0.024751     4.264239e-01
# 31      8.116326e-01            -0.007818     8.009664e-01
# 32      1.013540e-03            -0.104507     8.899399e-04
# 33      3.431389e-02            -0.066879     3.223159e-02
# 34      2.970427e-01            -0.033233     2.942093e-01
# 35      6.209563e-01            -0.015748     6.112301e-01
# 36      1.145491e-01            -0.051289     1.037646e-01
# 37      4.888894e-01            -0.022581     4.751903e-01
# 38      5.281469e-02             0.060803     4.989805e-02
# 39      8.513544e-01             0.005976     8.491284e-01
# 40      5.321556e-02             0.060284     5.255730e-02
# 41      5.255141e-05             0.125729     5.152182e-05
# 42      1.194775e-06             0.152028     9.820936e-07
# 43      7.667474e-01            -0.009507     7.625821e-01
# 44      7.311476e-01             0.010752     7.318296e-01
# 45      1.802753e-02             0.074377     1.746955e-02
#
# ============== Significance ====================
# Significant positive correlation: As the level of education increases, agreement on 'it is easy to navigate through the online platform to find the products or services i need' increases.
# Significant positive correlation: As the level of education increases, agreement on 'the online platform provides clear and intuitive navigation options' increases.
# No significant correlation between the level of education and 'it was easy for me to learn how to use the online platform for making online purchases' (p ≥ 0.05).
# No significant correlation between the level of education and 'i quickly became proficient in using the online platform for making online purchases during a crisis' (p ≥ 0.05).
# No significant correlation between the level of education and 'the instructions provided on the online platform are clear and easy to understand' (p ≥ 0.05).
# No significant correlation between the level of education and 'i can easily follow the instructions given on the online platform for making online purchases' (p ≥ 0.05).
# Significant positive correlation: As the level of education increases, agreement on 'the online platform responds quickly to my actions, such as loading pages and processing transactions.' increases.
# Significant positive correlation: As the level of education increases, agreement on 'i don't experience delays or long waiting times when using the online platform for making online purchases during a crisis' increases.
# Significant positive correlation: As the level of education increases, agreement on 'the online platform effectively handles errors or mistakes, such as providing clear error messages and easy recovery options' increases.
# Significant positive correlation: As the level of education increases, agreement on 'i rarely encounter errors or issues when using the online platform for making online purchases during a crisis' increases.
# Significant positive correlation: As the level of education increases, agreement on 'the online platform offers a wide range of products and services that meet my needs during a crisis' increases.
# Significant positive correlation: As the level of education increases, agreement on 'i can find the products or services i need on the online platform during a crisis' increases.
# Significant negative correlation: As the level of education increases, agreement on 'using the online platform for making purchases during a crisis is convenient and saves time' decreases.
# No significant correlation between the level of education and 'the online platform makes it easy to search for products and complete transactions during a crisis' (p ≥ 0.05).
# No significant correlation between the level of education and 'the online platform offers competitive prices, discounts, or cost-saving benefits during a crisis' (p ≥ 0.05).
# Significant negative correlation: As the level of education increases, agreement on 'i perceive that using the online platform for making purchases during a crisis can help me save money' decreases.
# No significant correlation between the level of education and 'the online platform provides detailed and accurate product information during a crisis' (p ≥ 0.05).
# No significant correlation between the level of education and 'i can easily access user reviews, ratings, and other relevant information to support my purchase decisions' (p ≥ 0.05).
# No significant correlation between the level of education and 'the online platform tailors recommendations, suggestions, or personalized offers based on my preferences' (p ≥ 0.05).
# Significant positive correlation: As the level of education increases, agreement on 'i feel that the online platform understands my needs and preferences during a crisis' increases.
# No significant correlation between the level of education and 'the online platform takes appropriate measures to protect my privacy' (p ≥ 0.05).
# Significant positive correlation: As the level of education increases, agreement on 'i trust that my personal information will be handled securely by the online platform' increases.
# No significant correlation between the level of education and 'the online platform provides secure payment methods to protect against fraudulent activities during a crisis' (p ≥ 0.05).
# No significant correlation between the level of education and 'i trust that my payment details are handled securely by the online platform' (p ≥ 0.05).
# No significant correlation between the level of education and 'the online platform provides clear and easily accessible policies regarding data handling, privacy, and security' (p ≥ 0.05).
# No significant correlation between the level of education and 'i feel confident in the online platform's transparency regarding its data protection practices' (p ≥ 0.05).
# No significant correlation between the level of education and 'i am influenced by recommendations and opinions from family and friends when making online purchases during a crisis' (p ≥ 0.05).
# No significant correlation between the level of education and 'i consider the experiences and suggestions shared by people i know before making online purchases during a crisis' (p ≥ 0.05).
# No significant correlation between the level of education and 'during a crisis, social media platforms, influencers, and online communities influence my online purchase decisions' (p ≥ 0.05).
# No significant correlation between the level of education and 'i am likely to make online purchases during a crisis based on what i see or learn from social media platforms' (p ≥ 0.05).
# No significant correlation between the level of education and 'i consider online reviews and ratings when making purchasing decisions during a crisis' (p ≥ 0.05).
# No significant correlation between the level of education and 'positive reviews and high ratings increase my confidence in making online purchases during a crisis' (p ≥ 0.05).
# Significant negative correlation: As the level of education increases, agreement on 'observing others making online purchases during a crisis influences my own intention to make similar purchases' decreases.
# Significant negative correlation: As the level of education increases, agreement on 'i am more likely to make online purchases during a crisis if i see others doing the same' decreases.
# No significant correlation between the level of education and 'social norms and expectations regarding online shopping during a crisis influence my own intention to make online purchases' (p ≥ 0.05).
# No significant correlation between the level of education and 'i feel pressure to make online purchases during a crisis due to the expectations of others' (p ≥ 0.05).
# No significant correlation between the level of education and 'i am willing to share my own online shopping experiences, recommendations, or opinions with others during a crisis' (p ≥ 0.05).
# No significant correlation between the level of education and 'sharing information about my online purchases during a crisis is important for influencing others' purchase decisions' (p ≥ 0.05).
# No significant correlation between the level of education and 'overall, i have a positive attitude toward online shopping during a crisis' (p ≥ 0.05).
# No significant correlation between the level of education and 'i believe that online shopping is a practical and efficient way to make purchases during a crisis' (p ≥ 0.05).
# No significant correlation between the level of education and 'i am concerned about the security of my personal and financial information when shopping online during a crisis' (p ≥ 0.05).
# Significant positive correlation: As the level of education increases, agreement on 'i am cautious about the reliability and authenticity of products or services offered by online platforms during a crisis' increases.
# Significant positive correlation: As the level of education increases, agreement on 'overall, i am satisfied with online purchase during a crisis?' increases.
# No significant correlation between the level of education and 'i have changed my online shopping behavior during a crisis compared to non-crisis periods?' (p ≥ 0.05).
# No significant correlation between the level of education and 'it was convenient for me to do online shopping during a crisis compared to traditional in-store shopping' (p ≥ 0.05).
# Significant positive correlation: As the level of education increases, agreement on 'i believe that online shopping during a crisis offers better value for money compared to traditional shopping methods' increases.

# %% [markdown]
# # Marital Status

# %%
df_copy2['marital status'].unique()
# Out:
# array([0, 1])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

marital_stat_map = {0: 'Single', 1: 'Married'}
df_copy2['marital_stat_label'] = df_copy2['marital status'].map(marital_stat_map)

# Countplot using seaborn
plt.figure(figsize=(4, 5))
sns.countplot(data=df_copy2, x='marital_stat_label', palette=['skyblue', 'lightpink', 'gray'])
plt.title('Marital Status Distribution')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
output_dir = '/kaggle/working/marital_status'
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# ## Marital Status vs Binary Features

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import zipfile
import warnings
from scipy.stats import chi2_contingency
import numpy as np

warnings.filterwarnings('ignore')

output_dir = '/kaggle/working/marital_status/binary_features/plots'
os.makedirs(output_dir, exist_ok=True)

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')

df_copy2['marital_status_str'] = df_copy2['marital status'].map({0: 'Single', 1: 'Married'})

marital_status_order = ['Single', 'Married']

binary_contingency_tables = []

for feature in binary_features:
    try:
        contingency_table = pd.crosstab(df_copy2['marital_status_str'], df_copy2[feature])
        
        contingency_table = contingency_table.reindex(marital_status_order)

        # Check for empty categories
        if (contingency_table == 0).any().any():
            print(f"Skipping chi-squared test for {feature}: Contingency table has empty categories (degenerate table).")
            chi2, p, cramers_v = None, None, None
        else:
            chi2, p, dof, expected = chi2_contingency(contingency_table)
            # Check expected frequencies
            if (expected < 1).any():
                print(f"Skipping chi-squared test for {feature}: Expected frequencies contain values less than 1.")
                chi2, p, cramers_v = None, None, None
            else:
                # Warn if expected frequencies are less than 5
                if (expected < 5).any():
                    print(f"Warning: Some expected frequencies for {feature} are less than 5, chi-squared test may be unreliable.")
                n = contingency_table.sum().sum()
                cramers_v = np.sqrt(chi2 / (n * (min(contingency_table.shape) - 1)))

                print(f"Feature: {feature}")
                print(f"Chi-Squared Statistic: {chi2:.3f}")
                print(f"P-Value: {p:.3f}")
                print(f"Cramér's V: {cramers_v:.3f}")
                if p < 0.05:
                    print("Result: There is a significant association between marital status and this feature (p < 0.05).\n")
                else:
                    print("Result: There is no significant association between marital status and this feature (p >= 0.05).\n")

        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Feature'] = feature
        contingency_table_reset['Chi2'] = chi2 if chi2 is not None else 'N/A'
        contingency_table_reset['P-Value'] = p if p is not None else 'N/A'
        contingency_table_reset["Cramér's V"] = cramers_v if cramers_v is not None else 'N/A'
        binary_contingency_tables.append(contingency_table_reset)

        # Visualize using stacked bar plot
        plt.figure(figsize=(8, 6))
        sns.countplot(data=df_copy2, x='marital_status_str', hue=feature, palette='Set2', order=marital_status_order)
        plt.title(f'Marital Status vs. {feature} Usage')
        plt.xlabel('Marital Status')
        plt.ylabel('Count')
        plt.legend(['Not Used', 'Used'])
        plt.tight_layout()
        filename = f"{output_dir}/marital_status_vs_{sanitize_filename(feature)}_stacked_bar.png"
        plt.savefig(filename)
        plt.close()
        #print(f"Saved plot: {filename}")
    except Exception as e:
        print(f"Failed to save plot for {feature}: {e}")
        plt.close()
        continue

if binary_contingency_tables:
    all_binary_tables_df = pd.concat(binary_contingency_tables, ignore_index=True)
    cols = ['Feature', 'Chi2', 'P-Value', "Cramér's V"] + [col for col in all_binary_tables_df.columns if col not in ['Feature', 'Chi2', 'P-Value', "Cramér's V"]]
    all_binary_tables_df = all_binary_tables_df[cols]
    output_xlsx = '/kaggle/working/marital_status/binary_features/binary_contingency_tables.xlsx'
    all_binary_tables_df.to_excel(output_xlsx, index=False)
    print(f"Saved binary contingency tables to: {output_xlsx}")
else:
    print("No binary contingency tables to save.")

zip_filename = '/kaggle/working/marital_status/binary_features/plots-binary.zip'
print(f"Creating ZIP file: {zip_filename}...")

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.png'):
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, '/kaggle/working/')
                zipf.write(file_path, arcname)

print(f"ZIP file created: {zip_filename}")

print("Chi-Squared Test for Marital Status vs. Binary Features completed.")
# Out:
# Warning: Some expected frequencies for have used online shopping platforms before are less than 5, chi-squared test may be unreliable.
# Feature: have used online shopping platforms before
# Chi-Squared Statistic: 0.000
# P-Value: 1.000
# Cramér's V: 0.000
# Result: There is no significant association between marital status and this feature (p >= 0.05).
#
# Feature: have you made online purchases during crisis time?
# Chi-Squared Statistic: 0.006
# P-Value: 0.939
# Cramér's V: 0.003
# Result: There is no significant association between marital status and this feature (p >= 0.05).
#
# Feature: ali-express
# Chi-Squared Statistic: 5.624
# P-Value: 0.018
# Cramér's V: 0.082
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: daraz
# Chi-Squared Statistic: 1.365
# P-Value: 0.243
# Cramér's V: 0.041
# Result: There is no significant association between marital status and this feature (p >= 0.05).
#
# Warning: Some expected frequencies for ebay are less than 5, chi-squared test may be unreliable.
# Feature: ebay
# Chi-Squared Statistic: 0.001
# P-Value: 0.969
# Cramér's V: 0.001
# Result: There is no significant association between marital status and this feature (p >= 0.05).
#
# Feature: ikman
# Chi-Squared Statistic: 0.079
# P-Value: 0.779
# Cramér's V: 0.010
# Result: There is no significant association between marital status and this feature (p >= 0.05).
#
# Skipping chi-squared test for instagram stores: Contingency table has empty categories (degenerate table).
# Feature: kapruka
# Chi-Squared Statistic: 19.191
# P-Value: 0.000
# Cramér's V: 0.152
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Skipping chi-squared test for keels: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for lassana.com: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for pickme: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for shein: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for strong.lk: Contingency table has empty categories (degenerate table).
# Feature: takas
# Chi-Squared Statistic: 22.932
# P-Value: 0.000
# Cramér's V: 0.166
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Warning: Some expected frequencies for wishque are less than 5, chi-squared test may be unreliable.
# Feature: wishque
# Chi-Squared Statistic: 1.226
# P-Value: 0.268
# Cramér's V: 0.038
# Result: There is no significant association between marital status and this feature (p >= 0.05).
#
# Feature: wow
# Chi-Squared Statistic: 40.536
# P-Value: 0.000
# Cramér's V: 0.221
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: amazon
# Chi-Squared Statistic: 5.624
# P-Value: 0.018
# Cramér's V: 0.082
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: autolanka.com
# Chi-Squared Statistic: 90.531
# P-Value: 0.000
# Cramér's V: 0.331
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: ikman.lk
# Chi-Squared Statistic: 24.214
# P-Value: 0.000
# Cramér's V: 0.171
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: lankavechicle.com
# Chi-Squared Statistic: 8.572
# P-Value: 0.003
# Cramér's V: 0.102
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: patpat.lk
# Chi-Squared Statistic: 2.910
# P-Value: 0.088
# Cramér's V: 0.059
# Result: There is no significant association between marital status and this feature (p >= 0.05).
#
# Feature: pricelanka.lk
# Chi-Squared Statistic: 40.507
# P-Value: 0.000
# Cramér's V: 0.221
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: riyasewana.lk
# Chi-Squared Statistic: 38.469
# P-Value: 0.000
# Cramér's V: 0.216
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: specialty online stores / automobile unknown
# Chi-Squared Statistic: 36.062
# P-Value: 0.000
# Cramér's V: 0.209
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Skipping chi-squared test for toyota: Contingency table has empty categories (degenerate table).
# Warning: Some expected frequencies for zero specialty online stores / automobile are less than 5, chi-squared test may be unreliable.
# Feature: zero specialty online stores / automobile
# Chi-Squared Statistic: 0.519
# P-Value: 0.471
# Cramér's V: 0.025
# Result: There is no significant association between marital status and this feature (p >= 0.05).
#
# Feature: ceymed.lk
# Chi-Squared Statistic: 19.729
# P-Value: 0.000
# Cramér's V: 0.154
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: epharma.lk
# Chi-Squared Statistic: 17.138
# P-Value: 0.000
# Cramér's V: 0.144
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: healthgurd.lk
# Chi-Squared Statistic: 64.428
# P-Value: 0.000
# Cramér's V: 0.279
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: healthnet.lk
# Chi-Squared Statistic: 56.263
# P-Value: 0.000
# Cramér's V: 0.261
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: nearby pharmacy
# Chi-Squared Statistic: 9.637
# P-Value: 0.002
# Cramér's V: 0.108
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Warning: Some expected frequencies for no online pharmacies are less than 5, chi-squared test may be unreliable.
# Feature: no online pharmacies
# Chi-Squared Statistic: 0.074
# P-Value: 0.786
# Cramér's V: 0.009
# Result: There is no significant association between marital status and this feature (p >= 0.05).
#
# Feature: online pharmacy unknown
# Chi-Squared Statistic: 21.982
# P-Value: 0.000
# Cramér's V: 0.163
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: onlinepharmacy.lk
# Chi-Squared Statistic: 9.582
# P-Value: 0.002
# Cramér's V: 0.108
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Skipping chi-squared test for union chemist: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for amanthe: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for carlo clothing: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for carnage,: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for chenara dodge: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for dsi: Contingency table has empty categories (degenerate table).
# Feature: fashionbug.lk
# Chi-Squared Statistic: 24.782
# P-Value: 0.000
# Cramér's V: 0.173
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: gflock
# Chi-Squared Statistic: 6.002
# P-Value: 0.014
# Cramér's V: 0.085
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: kapruka.com/fashion
# Chi-Squared Statistic: 30.143
# P-Value: 0.000
# Cramér's V: 0.191
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: kelly felder
# Chi-Squared Statistic: 3.387
# P-Value: 0.066
# Cramér's V: 0.064
# Result: There is no significant association between marital status and this feature (p >= 0.05).
#
# Skipping chi-squared test for kynd fashion: Contingency table has empty categories (degenerate table).
# Feature: midnightdivas.com
# Chi-Squared Statistic: 0.043
# P-Value: 0.836
# Cramér's V: 0.007
# Result: There is no significant association between marital status and this feature (p >= 0.05).
#
# Skipping chi-squared test for mimosa: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for moods: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for moose: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for nills: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for no fashion and beauty retailers: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for nolimit.lk: Contingency table has empty categories (degenerate table).
# Skipping chi-squared test for noorareed.lk: Contingency table has empty categories (degenerate table).
# Feature: odel.lk
# Chi-Squared Statistic: 6.019
# P-Value: 0.014
# Cramér's V: 0.085
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Skipping chi-squared test for s&s: Contingency table has empty categories (degenerate table).
# Feature: spring and summer
# Chi-Squared Statistic: 0.789
# P-Value: 0.374
# Cramér's V: 0.031
# Result: There is no significant association between marital status and this feature (p >= 0.05).
#
# Skipping chi-squared test for tharshana and insta shops: Contingency table has empty categories (degenerate table).
# Feature: thilakawardana.lk
# Chi-Squared Statistic: 2.638
# P-Value: 0.104
# Cramér's V: 0.056
# Result: There is no significant association between marital status and this feature (p >= 0.05).
#
# Feature: unknown fashion and beauty retailers
# Chi-Squared Statistic: 11.593
# P-Value: 0.001
# Cramér's V: 0.118
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Skipping chi-squared test for zigzag.lk: Contingency table has empty categories (degenerate table).
# Feature: arpico.lk
# Chi-Squared Statistic: 6.931
# P-Value: 0.008
# Cramér's V: 0.091
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Skipping chi-squared test for cargillsonline.com: Contingency table has empty categories (degenerate table).
# Feature: cinnamonhotel.com
# Chi-Squared Statistic: 4.113
# P-Value: 0.043
# Cramér's V: 0.070
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Warning: Some expected frequencies for glomark.lk are less than 5, chi-squared test may be unreliable.
# Feature: glomark.lk
# Chi-Squared Statistic: 0.140
# P-Value: 0.708
# Cramér's V: 0.013
# Result: There is no significant association between marital status and this feature (p >= 0.05).
#
# Skipping chi-squared test for grocery delivery services not used: Contingency table has empty categories (degenerate table).
# Feature: keellssuper.lk
# Chi-Squared Statistic: 35.338
# P-Value: 0.000
# Cramér's V: 0.207
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: pickmefoods.com
# Chi-Squared Statistic: 38.830
# P-Value: 0.000
# Cramér's V: 0.217
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: ubereats.com
# Chi-Squared Statistic: 49.051
# P-Value: 0.000
# Cramér's V: 0.243
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Feature: unknown grocery delivery services
# Chi-Squared Statistic: 8.413
# P-Value: 0.004
# Cramér's V: 0.101
# Result: There is a significant association between marital status and this feature (p < 0.05).
#
# Saved binary contingency tables to: /kaggle/working/marital_status/binary_features/binary_contingency_tables.xlsx
# Creating ZIP file: /kaggle/working/marital_status/binary_features/plots-binary.zip...
# ZIP file created: /kaggle/working/marital_status/binary_features/plots-binary.zip
# Chi-Squared Test for Marital Status vs. Binary Features completed.

# %% [markdown]
# ## Marital Status vs Platform Groups

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import zipfile
import warnings
from scipy.stats import chi2_contingency
import numpy as np

warnings.filterwarnings('ignore')

output_dir = '/kaggle/working/marital_status/platform_groups/plots'
os.makedirs(output_dir, exist_ok=True)

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')

df_copy2['marital_status_str'] = df_copy2['marital status'].map({0: 'Single', 1: 'Married'})

marital_status_order = ['Single', 'Married']

platform_groups = [
    'general e-commerce platforms', 'specialty online stores / automobile', 'online pharmacies', 
    'fashion and beauty retailers', 'grocery delivery services'
]

not_used_values = {
    'general e-commerce platforms': None,  # No explicit "not used" value
    'specialty online stores / automobile': 'zero specialty online stores / automobile',
    'online pharmacies': 'no online pharmacies',
    'fashion and beauty retailers': 'no fashion and beauty retailers',
    'grocery delivery services': 'grocery delivery services not used'
}

unknown_values = {
    'general e-commerce platforms': None,  # No explicit "unknown" value
    'specialty online stores / automobile': 'specialty online stores / automobile unknown',
    'online pharmacies': 'online pharmacy unknown',
    'fashion and beauty retailers': 'unknown fashion and beauty retailers',
    'grocery delivery services': 'unknown grocery delivery services'
}

for group in platform_groups:
    df_copy2[f'{group}_status'] = df_copy2[group].apply(
        lambda x: 'unknown' if pd.isna(x) or (group in unknown_values and x == unknown_values[group])
        else 'not used' if group in not_used_values and x == not_used_values[group]
        else 'used'
    )

platform_group_status = [f'{group}_status' for group in platform_groups]

status_order = ['used', 'not used', 'unknown']

print("Mappings for 'not used' and 'unknown' values in platform_groups:")
for group in platform_groups:
    print(f"\nPlatform Group: {group}")
    print(f"Not Used Value: {not_used_values[group]}")
    print(f"Unknown Value: {unknown_values[group]}")

platform_groups_contingency_tables = []

for group_status in platform_group_status:
    try:
        contingency_table = pd.crosstab(df_copy2['marital_status_str'], df_copy2[group_status])
        
        contingency_table = contingency_table.reindex(marital_status_order)
        
        contingency_table = contingency_table.reindex(columns=status_order, fill_value=0)

        chi2, p, dof, expected = chi2_contingency(contingency_table)
        n = contingency_table.sum().sum()
        cramers_v = np.sqrt(chi2 / (n * (min(contingency_table.shape) - 1)))

        # Print p-value and association result
        group_name = group_status.replace('_status', '')
        print(f"Platform Group: {group_name}")
        
        # Check for degenerate table (fewer than 2 non-zero rows or columns)
        non_zero_rows = (contingency_table != 0).any(axis=1).sum()
        non_zero_cols = (contingency_table != 0).any(axis=0).sum()
        if non_zero_rows < 2 or non_zero_cols < 2:
            print(f"Skipping test for {group_name}: Contingency table is degenerate (fewer than 2 non-zero rows or columns).")
            chi2, p, cramers_v = None, None, None
        else:
            chi2, p, dof, expected = chi2_contingency(contingency_table)

            # Check expected frequencies
            if (expected < 1).any():
                # For 2x2 tables, use Fisher’s exact test
                if contingency_table.shape == (2, 2):
                    print("Using Fisher’s exact test due to expected frequencies less than 1.")
                    _, p = fisher_exact(contingency_table)
                    chi2, cramers_v = None, None
                else:
                    print(f"Skipping chi-squared test for {group_name}: Expected frequencies contain values less than 1.")
                    chi2, p, cramers_v = None, None, None
            else:
                if (expected < 5).any():
                    print("Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.")
                n = contingency_table.sum().sum()
                cramers_v = np.sqrt(chi2 / (n * (min(contingency_table.shape) - 1)))

                print(f"Chi-Squared Statistic: {chi2:.3f}")
                print(f"P-Value: {p:.3f}")
                print(f"Cramér's V: {cramers_v:.3f}")
                if p < 0.05:
                    print("Result: There is a significant association between marital status and this platform group (p < 0.05).\n")
                else:
                    print("Result: There is no significant association between marital status and this platform group (p >= 0.05).\n")

        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Platform Group'] = group_name
        contingency_table_reset['Chi2'] = chi2 if chi2 is not None else 'N/A'
        contingency_table_reset['P-Value'] = p if p is not None else 'N/A'
        contingency_table_reset["Cramér's V"] = cramers_v if cramers_v is not None else 'N/A'
        platform_groups_contingency_tables.append(contingency_table_reset)

        plt.figure(figsize=(8, 6))
        sns.countplot(
            data=df_copy2, 
            x='marital_status_str', 
            hue=group_status, 
            hue_order=status_order, 
            palette='Set2', 
            order=marital_status_order
        )
        plt.title(f'Marital Status vs. {group_name} Usage')
        plt.xlabel('Marital Status')
        plt.ylabel('Count')
        plt.legend(title='Usage Status', labels=['Used', 'Not Used', 'Unknown'])
        plt.tight_layout()
        filename = f"{output_dir}/marital_status_vs_{sanitize_filename(group_status)}_stacked_bar.png"
        plt.savefig(filename)
        plt.close()
        #print(f"Saved plot: {filename}")
    except Exception as e:
        print(f"Failed to save plot for {group_status}: {e}\n")
        plt.close()
        continue

if platform_groups_contingency_tables:
    all_platform_tables_df = pd.concat(platform_groups_contingency_tables, ignore_index=True)
    cols = ['Platform Group', 'Chi2', 'P-Value', "Cramér's V"] + [col for col in all_platform_tables_df.columns if col not in ['Platform Group', 'Chi2', 'P-Value', "Cramér's V"]]
    all_platform_tables_df = all_platform_tables_df[cols]
    output_xlsx = '/kaggle/working/marital_status/platform_groups/platform_groups_contingency_tables.xlsx'
    all_platform_tables_df.to_excel(output_xlsx, index=False)
    print(f"Saved platform groups contingency tables to: {output_xlsx}")
else:
    print("No platform groups contingency tables to save.")

zip_filename = '/kaggle/working/marital_status/platform_groups/plots-platforms.zip'
print(f"Updating ZIP file: {zip_filename}...")

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.png'):
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, '/kaggle/working/')
                zipf.write(file_path, arcname)

print(f"ZIP file updated: {zip_filename}")

print("Chi-Squared Test for Marital Status vs. Platform Groups completed.")
# Out:
# Mappings for 'not used' and 'unknown' values in platform_groups:
#
# Platform Group: general e-commerce platforms
# Not Used Value: None
# Unknown Value: None
#
# Platform Group: specialty online stores / automobile
# Not Used Value: zero specialty online stores / automobile
# Unknown Value: specialty online stores / automobile unknown
#
# Platform Group: online pharmacies
# Not Used Value: no online pharmacies
# Unknown Value: online pharmacy unknown
#
# Platform Group: fashion and beauty retailers
# Not Used Value: no fashion and beauty retailers
# Unknown Value: unknown fashion and beauty retailers
#
# Platform Group: grocery delivery services
# Not Used Value: grocery delivery services not used
# Unknown Value: unknown grocery delivery services
# Failed to save plot for general e-commerce platforms_status: The internally computed table of expected frequencies has a zero element at (0, 1).
#
# Platform Group: specialty online stores / automobile
# Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.
# Chi-Squared Statistic: 39.082
# P-Value: 0.000
# Cramér's V: 0.217
# Result: There is a significant association between marital status and this platform group (p < 0.05).
#
# Platform Group: online pharmacies
# Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.
# Chi-Squared Statistic: 23.601
# P-Value: 0.000
# Cramér's V: 0.169
# Result: There is a significant association between marital status and this platform group (p < 0.05).
#
# Platform Group: fashion and beauty retailers
# Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.
# Chi-Squared Statistic: 17.754
# P-Value: 0.000
# Cramér's V: 0.146
# Result: There is a significant association between marital status and this platform group (p < 0.05).
#
# Platform Group: grocery delivery services
# Skipping chi-squared test for grocery delivery services: Expected frequencies contain values less than 1.
# Saved platform groups contingency tables to: /kaggle/working/marital_status/platform_groups/platform_groups_contingency_tables.xlsx
# Updating ZIP file: /kaggle/working/marital_status/platform_groups/plots-platforms.zip...
# ZIP file updated: /kaggle/working/marital_status/platform_groups/plots-platforms.zip
# Chi-Squared Test for Marital Status vs. Platform Groups completed.

# %% [markdown]
# ## Marital Status vs Other Features

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import zipfile
import warnings

warnings.filterwarnings('ignore')

output_dir = '/kaggle/working/marital_status/other_features/plots'
os.makedirs(output_dir, exist_ok=True)

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')

df_copy2['marital_status_str'] = df_copy2['marital status'].map({0: 'Single', 1: 'Married'})

marital_status_order = ['Single', 'Married']

agreement_mapping = {
    0: 'Strongly Disagree',
    1: 'Disagree',
    2: 'Neutral',
    3: 'Agree',
    4: 'Strongly Agree'
}

# Define order for agreement levels
agreement_order = ['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree']

for feature in other_features:
    df_copy2[f'{feature}_str'] = df_copy2[feature].map(agreement_mapping)

other_features_str = [f'{feature}_str' for feature in other_features]

other_features_contingency_tables = []

for feature_str in other_features_str:
    try:
        contingency_table = pd.crosstab(df_copy2['marital_status_str'], df_copy2[feature_str])
        
        contingency_table = contingency_table.reindex(marital_status_order)
        contingency_table = contingency_table.reindex(columns=agreement_order, fill_value=0)

        # Store contingency table
        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Feature'] = feature_str.replace('_str', '')  
        other_features_contingency_tables.append(contingency_table_reset)

        plt.figure(figsize=(8, 6))
        sns.countplot(
            data=df_copy2, 
            x='marital_status_str', 
            hue=feature_str, 
            hue_order=agreement_order, 
            palette='Set2', 
            order=marital_status_order
        )
        plt.title(f'Marital Status vs. {feature_str.replace("_str", "")}')
        plt.xlabel('Marital Status')
        plt.ylabel('Count')
        plt.legend(title='Agreement Level')
        plt.tight_layout()
        filename = f"{output_dir}/marital_status_vs_{sanitize_filename(feature_str)}_stacked_bar.png"
        plt.savefig(filename)
        plt.close()
        print(f"Saved plot: {filename}")
    except Exception as e:
        print(f"Failed to process {feature_str}: {e}")
        plt.close()
        continue

if other_features_contingency_tables:
    all_other_features_tables_df = pd.concat(other_features_contingency_tables, ignore_index=True)
    
    cols = ['Feature', 'marital_status_str'] + agreement_order
    all_other_features_tables_df = all_other_features_tables_df[cols]
    output_xlsx = '/kaggle/working/marital_status/other_features/other_features_contingency_tables.xlsx'
    all_other_features_tables_df.to_excel(output_xlsx, index=False)
    print(f"Saved other features contingency tables to: {output_xlsx}")
else:
    print("No other features contingency tables to save.")

zip_filename = '/kaggle/working/marital_status/other_features/plots-other_features-association.zip'
print(f"Updating ZIP file: {zip_filename}...")

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.png'):
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, '/kaggle/working/')
                zipf.write(file_path, arcname)

print(f"ZIP file updated: {zip_filename}")

print("EDA for Marital Status vs. Other Features completed. Plots saved as PNG files")
# Out:
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_it_is_easy_to_navigate_through_the_online_platform_to_find_the_products_or_services_i_need_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_the_online_platform_provides_clear_and_intuitive_navigation_options_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_it_was_easy_for_me_to_learn_how_to_use_the_online_platform_for_making_online_purchases_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_quickly_became_proficient_in_using_the_online_platform_for_making_online_purchases_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_the_instructions_provided_on_the_online_platform_are_clear_and_easy_to_understand_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_can_easily_follow_the_instructions_given_on_the_online_platform_for_making_online_purchases_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_the_online_platform_responds_quickly_to_my_actions__such_as_loading_pages_and_processing_transactions__str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_don_t_experience_delays_or_long_waiting_times_when_using_the_online_platform_for_making_online_purchases_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_the_online_platform_effectively_handles_errors_or_mistakes__such_as_providing_clear_error_messages_and_easy_recovery_options_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_rarely_encounter_errors_or_issues_when_using_the_online_platform_for_making_online_purchases_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_the_online_platform_offers_a_wide_range_of_products_and_services_that_meet_my_needs_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_can_find_the_products_or_services_i_need_on_the_online_platform_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_using_the_online_platform_for_making_purchases_during_a_crisis_is_convenient_and_saves_time_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_the_online_platform_makes_it_easy_to_search_for_products_and_complete_transactions_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_the_online_platform_offers_competitive_prices__discounts__or_cost-saving_benefits_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_perceive_that_using_the_online_platform_for_making_purchases_during_a_crisis_can_help_me_save_money_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_the_online_platform_provides_detailed_and_accurate_product_information_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_can_easily_access_user_reviews__ratings__and_other_relevant_information_to_support_my_purchase_decisions_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_the_online_platform_tailors_recommendations__suggestions__or_personalized_offers_based_on_my_preferences_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_feel_that_the_online_platform_understands_my_needs_and_preferences_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_the_online_platform_takes_appropriate_measures_to_protect_my_privacy_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_trust_that_my_personal_information_will_be_handled_securely_by_the_online_platform_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_the_online_platform_provides_secure_payment_methods_to_protect_against_fraudulent_activities_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_trust_that_my_payment_details_are_handled_securely_by_the_online_platform_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_the_online_platform_provides_clear_and_easily_accessible_policies_regarding_data_handling__privacy__and_security_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_feel_confident_in_the_online_platform_s_transparency_regarding_its_data_protection_practices_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_am_influenced_by_recommendations_and_opinions_from_family_and_friends_when_making_online_purchases_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_consider_the_experiences_and_suggestions_shared_by_people_i_know_before_making_online_purchases_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_during_a_crisis__social_media_platforms__influencers__and_online_communities_influence_my_online_purchase_decisions_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_am_likely_to_make_online_purchases_during_a_crisis_based_on_what_i_see_or_learn_from_social_media_platforms_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_consider_online_reviews_and_ratings_when_making_purchasing_decisions_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_positive_reviews_and_high_ratings_increase_my_confidence_in_making_online_purchases_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_observing_others_making_online_purchases_during_a_crisis_influences_my_own_intention_to_make_similar_purchases_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_am_more_likely_to_make_online_purchases_during_a_crisis_if_i_see_others_doing_the_same_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_social_norms_and_expectations_regarding_online_shopping_during_a_crisis_influence_my_own_intention_to_make_online_purchases_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_feel_pressure_to_make_online_purchases_during_a_crisis_due_to_the_expectations_of_others_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_am_willing_to_share_my_own_online_shopping_experiences__recommendations__or_opinions_with_others_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_sharing_information_about_my_online_purchases_during_a_crisis_is_important_for_influencing_others__purchase_decisions_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_overall__i_have_a_positive_attitude_toward_online_shopping_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_believe_that_online_shopping_is_a_practical_and_efficient_way_to_make_purchases_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_am_concerned_about_the_security_of_my_personal_and_financial_information_when_shopping_online_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_am_cautious_about_the_reliability_and_authenticity_of_products_or_services_offered_by_online_platforms_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_overall__i_am_satisfied_with_online_purchase_during_a_crisis__str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_have_changed_my_online_shopping_behavior_during_a_crisis_compared_to_non-crisis_periods__str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_it_was_convenient_for_me_to_do_online_shopping_during_a_crisis_compared_to_traditional_in-store_shopping_str_stacked_bar.png
# Saved plot: /kaggle/working/marital_status/other_features/plots/marital_status_vs_i_believe_that_online_shopping_during_a_crisis_offers_better_value_for_money_compared_to_traditional_shopping_methods_str_stacked_bar.png
# Saved other features contingency tables to: /kaggle/working/marital_status/other_features/other_features_contingency_tables.xlsx
# Updating ZIP file: /kaggle/working/marital_status/other_features/plots-other_features-association.zip...
# ZIP file updated: /kaggle/working/marital_status/other_features/plots-other_features-association.zip
# EDA for Marital Status vs. Other Features completed. Plots saved as PNG files

# %% [markdown]
# # Professional Background

# %%
df_copy2['professional background'].unique()
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# *"professional background" is factorized in the preprocessed dataset. So I ran the following code to get the mapping of after factorizing and the output was as given below:* <br>
# **Code:** <br>
# ```python
# codes, uniques = pd.factorize(df_copy['professional background'])
# print(dict(enumerate(uniques)))
# ```
# **Output:** <br>
# {0: 'Employed (full-time)', 1: 'Employed (part-time)', 2: 'Student', 3: 'Unemployed', 4: 'Self-employed / Entrepreneur'}

# %% [markdown]
# * **Professional Background is Nominal**

# %%
profession_map = {0: 'Employed (full-time)', 1: 'Employed (part-time)', 2: 'Student', 3: 'Unemployed', 4: 'Self-employed / Entrepreneur'}
df_copy2['profession_label'] = df_copy2['professional background'].map(profession_map)

# Countplot using seaborn
plt.figure(figsize=(8, 6))
sns.countplot(data=df_copy2, x='profession_label', palette=['skyblue', 'lightpink', 'gray'])
plt.title('Professional Background Distribution')
plt.xlabel('professional background')
plt.ylabel('Count')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Professional Background vs Binary Features

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import zipfile
import warnings
from scipy.stats import chi2_contingency
import numpy as np

warnings.filterwarnings('ignore')

output_dir = '/kaggle/working/profession/binary_features/plots'
os.makedirs(output_dir, exist_ok=True)

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')

binary_contingency_tables = []

prof_background_mapping = {
    0: 'Employed (full-time)',
    1: 'Employed (part-time)',
    2: 'Students',
    3: 'Unemployed',
    4: 'Self-employed / Entrepreneur'
}
df_copy2['professional_background_str'] = df_copy2['professional background'].map(prof_background_mapping)

for feature in binary_features:
    try:
        contingency_table = pd.crosstab(df_copy2['professional background'], df_copy2[feature])

        if (contingency_table == 0).any().any():
            print(f"Skipping chi-squared test for {feature}: Contingency table has empty categories.")
            chi2, p, cramers_v = None, None, None
        else:
            chi2, p, dof, expected = chi2_contingency(contingency_table)
            if (expected < 1).any():
                print(f"Skipping chi-squared test for {feature}: Expected frequencies contain values less than 1.")
                chi2, p, cramers_v = None, None, None
            else:
                n = contingency_table.sum().sum()
                cramers_v = np.sqrt(chi2 / (n * (min(contingency_table.shape) - 1)))

                print(f"Feature: {feature}")
                print(f"Chi-Squared Statistic: {chi2:.3f}")
                print(f"P-Value: {p:.3f}")
                print(f"Cramér's V: {cramers_v:.3f}")
                if p < 0.05:
                    print("Result: There is a significant association between professional background and this feature (p < 0.05).")
                else:
                    print("Result: There is no significant association between professional background and this feature (p >= 0.05).")

        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Feature'] = feature
        contingency_table_reset['Chi2'] = chi2 if chi2 is not None else 'N/A'
        contingency_table_reset['P-Value'] = p if p is not None else 'N/A'
        contingency_table_reset["Cramér's V"] = cramers_v if cramers_v is not None else 'N/A'
        binary_contingency_tables.append(contingency_table_reset)

        plt.figure(figsize=(8, 6))
        sns.countplot(
            data=df_copy2, 
            x='professional_background_str', 
            hue=feature, 
            palette='Set2',
            order=['Employed (full-time)', 'Employed (part-time)', 'Students', 'Unemployed', 'Self-employed / Entrepreneur']
        )
        plt.title(f'Professional Background vs. {feature}')
        plt.xlabel('Professional Background')
        plt.ylabel('Count')
        plt.legend(title='Usage', labels=['No', 'Yes'])
        plt.xticks(rotation=45)
        plt.tight_layout()
        filename = f"{output_dir}/professional_background_vs_{sanitize_filename(feature)}_stacked_bar.png"
        plt.savefig(filename)
        plt.close()
        #print(f"Saved plot: {filename}")

    except Exception as e:
        print(f"Failed to process {feature}: {e}")
        continue

if binary_contingency_tables:
    all_binary_tables_df = pd.concat(binary_contingency_tables, ignore_index=True)
    cols = ['Feature', 'Chi2', 'P-Value', "Cramér's V"] + [col for col in all_binary_tables_df.columns if col not in ['Feature', 'Chi2', 'P-Value', "Cramér's V"]]
    all_binary_tables_df = all_binary_tables_df[cols]
    output_xlsx = '/kaggle/working/profession/binary_features/binary_features_contingency_tables.xlsx'
    all_binary_tables_df.to_excel(output_xlsx, index=False)
    print(f"Saved binary features contingency tables to: {output_xlsx}")
else:
    print("No binary features contingency tables to save.")

zip_filename = '/kaggle/working/profession/binary_features/plots-binary.zip'
print(f"Updating ZIP file: {zip_filename}...")

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.png'):
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, '/kaggle/working/')
                zipf.write(file_path, arcname)

print(f"ZIP file updated: {zip_filename}")

print("Chi-Squared Test for Professional Background vs. Binary Features completed.")
# Out:
# Skipping chi-squared test for have used online shopping platforms before: Contingency table has empty categories.
# Skipping chi-squared test for have you made online purchases during crisis time?: Expected frequencies contain values less than 1.
# Skipping chi-squared test for ali-express: Contingency table has empty categories.
# Skipping chi-squared test for daraz: Contingency table has empty categories.
# Skipping chi-squared test for ebay: Contingency table has empty categories.
# Skipping chi-squared test for ikman: Contingency table has empty categories.
# Skipping chi-squared test for instagram stores: Contingency table has empty categories.
# Skipping chi-squared test for kapruka: Expected frequencies contain values less than 1.
# Skipping chi-squared test for keels: Contingency table has empty categories.
# Skipping chi-squared test for lassana.com: Contingency table has empty categories.
# Skipping chi-squared test for pickme: Contingency table has empty categories.
# Skipping chi-squared test for shein: Contingency table has empty categories.
# Skipping chi-squared test for strong.lk: Contingency table has empty categories.
# Skipping chi-squared test for takas: Contingency table has empty categories.
# Skipping chi-squared test for wishque: Contingency table has empty categories.
# Skipping chi-squared test for wow: Contingency table has empty categories.
# Skipping chi-squared test for amazon: Contingency table has empty categories.
# Skipping chi-squared test for autolanka.com: Contingency table has empty categories.
# Skipping chi-squared test for ikman.lk: Contingency table has empty categories.
# Skipping chi-squared test for lankavechicle.com: Contingency table has empty categories.
# Skipping chi-squared test for patpat.lk: Expected frequencies contain values less than 1.
# Skipping chi-squared test for pricelanka.lk: Contingency table has empty categories.
# Feature: riyasewana.lk
# Chi-Squared Statistic: 56.355
# P-Value: 0.000
# Cramér's V: 0.261
# Result: There is a significant association between professional background and this feature (p < 0.05).
# Skipping chi-squared test for specialty online stores / automobile unknown: Contingency table has empty categories.
# Skipping chi-squared test for toyota: Contingency table has empty categories.
# Skipping chi-squared test for zero specialty online stores / automobile: Contingency table has empty categories.
# Skipping chi-squared test for ceymed.lk: Contingency table has empty categories.
# Skipping chi-squared test for epharma.lk: Contingency table has empty categories.
# Skipping chi-squared test for healthgurd.lk: Contingency table has empty categories.
# Skipping chi-squared test for healthnet.lk: Contingency table has empty categories.
# Skipping chi-squared test for nearby pharmacy: Contingency table has empty categories.
# Skipping chi-squared test for no online pharmacies: Contingency table has empty categories.
# Skipping chi-squared test for online pharmacy unknown: Contingency table has empty categories.
# Skipping chi-squared test for onlinepharmacy.lk: Expected frequencies contain values less than 1.
# Skipping chi-squared test for union chemist: Contingency table has empty categories.
# Skipping chi-squared test for amanthe: Contingency table has empty categories.
# Skipping chi-squared test for carlo clothing: Contingency table has empty categories.
# Skipping chi-squared test for carnage,: Contingency table has empty categories.
# Skipping chi-squared test for chenara dodge: Contingency table has empty categories.
# Skipping chi-squared test for dsi: Contingency table has empty categories.
# Skipping chi-squared test for fashionbug.lk: Contingency table has empty categories.
# Skipping chi-squared test for gflock: Contingency table has empty categories.
# Skipping chi-squared test for kapruka.com/fashion: Contingency table has empty categories.
# Skipping chi-squared test for kelly felder: Contingency table has empty categories.
# Skipping chi-squared test for kynd fashion: Contingency table has empty categories.
# Skipping chi-squared test for midnightdivas.com: Contingency table has empty categories.
# Skipping chi-squared test for mimosa: Contingency table has empty categories.
# Skipping chi-squared test for moods: Contingency table has empty categories.
# Skipping chi-squared test for moose: Contingency table has empty categories.
# Skipping chi-squared test for nills: Contingency table has empty categories.
# Skipping chi-squared test for no fashion and beauty retailers: Contingency table has empty categories.
# Skipping chi-squared test for nolimit.lk: Contingency table has empty categories.
# Skipping chi-squared test for noorareed.lk: Contingency table has empty categories.
# Skipping chi-squared test for odel.lk: Expected frequencies contain values less than 1.
# Skipping chi-squared test for s&s: Contingency table has empty categories.
# Skipping chi-squared test for spring and summer: Contingency table has empty categories.
# Skipping chi-squared test for tharshana and insta shops: Contingency table has empty categories.
# Skipping chi-squared test for thilakawardana.lk: Contingency table has empty categories.
# Skipping chi-squared test for unknown fashion and beauty retailers: Contingency table has empty categories.
# Skipping chi-squared test for zigzag.lk: Contingency table has empty categories.
# Skipping chi-squared test for arpico.lk: Contingency table has empty categories.
# Skipping chi-squared test for cargillsonline.com: Contingency table has empty categories.
# Skipping chi-squared test for cinnamonhotel.com: Contingency table has empty categories.
# Skipping chi-squared test for glomark.lk: Contingency table has empty categories.
# Skipping chi-squared test for grocery delivery services not used: Contingency table has empty categories.
# Skipping chi-squared test for keellssuper.lk: Expected frequencies contain values less than 1.
# Skipping chi-squared test for pickmefoods.com: Contingency table has empty categories.
# Skipping chi-squared test for ubereats.com: Expected frequencies contain values less than 1.
# Skipping chi-squared test for unknown grocery delivery services: Contingency table has empty categories.
# Saved binary features contingency tables to: /kaggle/working/profession/binary_features/binary_features_contingency_tables.xlsx
# Updating ZIP file: /kaggle/working/profession/binary_features/plots-binary.zip...
# ZIP file updated: /kaggle/working/profession/binary_features/plots-binary.zip
# Chi-Squared Test for Professional Background vs. Binary Features completed.

# %% [markdown]
# The primary reason chi-squared tests were skipped for these features is the small sample size of certain professional background categories, specifically:
#
#  - Employed (part-time): Only 10 respondents.
#  - Unemployed: Only 3 respondents.
#
# These small row totals lead to very low expected frequencies (often < 1) in some cells, especially when paired with columns that have imbalanced totals (e.g., column 0 for have you made online purchases during crisis time? has only 27 respondents, while column 1 has 801). The chi-squared test cannot be reliably performed when expected frequencies fall below 1.

# %% [markdown]
# ## Professional Background vs Platform Groups

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import zipfile
import warnings
from scipy.stats import chi2_contingency
import numpy as np

warnings.filterwarnings('ignore')

output_dir = '/kaggle/working/profession/platform_groups/plots'
os.makedirs(output_dir, exist_ok=True)

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')

# Map professional background to meaningful labels
prof_background_mapping = {
    0: 'Employed (full-time)',
    1: 'Employed (part-time)',
    2: 'Student',
    3: 'Unemployed',
    4: 'Self-employed / Entrepreneur'
}
df_copy2['professional_background_str'] = df_copy2['professional background'].map(prof_background_mapping)

professional_background_order = [
    'Employed (full-time)', 'Employed (part-time)', 'Student', 'Unemployed', 
    'Self-employed / Entrepreneur'
]

# Define platform groups, not used, and unknown values
platform_groups = [
    'general e-commerce platforms', 'specialty online stores / automobile', 'online pharmacies', 
    'fashion and beauty retailers', 'grocery delivery services'
]

not_used_values = {
    'general e-commerce platforms': None,
    'specialty online stores / automobile': 'zero specialty online stores / automobile',
    'online pharmacies': 'no online pharmacies',
    'fashion and beauty retailers': 'no fashion and beauty retailers',
    'grocery delivery services': 'grocery delivery services not used'
}

unknown_values = {
    'general e-commerce platforms': None,
    'specialty online stores / automobile': 'specialty online stores / automobile unknown',
    'online pharmacies': 'online pharmacy unknown',
    'fashion and beauty retailers': 'unknown fashion and beauty retailers',
    'grocery delivery services': 'unknown grocery delivery services'
}

# Categorize platform usage into 'used', 'not used', 'unknown'
for group in platform_groups:
    df_copy2[f'{group}_status'] = df_copy2[group].apply(
        lambda x: 'unknown' if pd.isna(x) or (group in unknown_values and x == unknown_values[group])
        else 'not used' if group in not_used_values and x == not_used_values[group]
        else 'used'
    )

    # Also create a binary usage column for chi-squared tests, excluding 'unknown'
    df_copy2[f'{group}_binary_usage'] = df_copy2[group].apply(
        lambda x: np.nan if pd.isna(x) or (group in unknown_values and x == unknown_values[group])
        else 0 if group in not_used_values and x == not_used_values[group]
        else 1
    )

platform_group_status = [f'{group}_status' for group in platform_groups]
status_order = ['used', 'not used', 'unknown']

# Print mappings for verification
print("Mappings for 'not used' and 'unknown' values in platform_groups:")
for group in platform_groups:
    print(f"\nPlatform Group: {group}")
    print(f"Not Used Value: {not_used_values[group]}")
    print(f"Unknown Value: {unknown_values[group]}")

platform_groups_contingency_tables = []

for group in platform_groups:
    group_status = f'{group}_status'
    group_binary = f'{group}_binary_usage'
    try:
        # Create binary contingency table (excluding 'unknown') for chi-squared test
        df_binary = df_copy2.dropna(subset=[group_binary])
        contingency_table_binary = pd.crosstab(df_binary['professional_background_str'], df_binary[group_binary])
        contingency_table_binary = contingency_table_binary.reindex(index=professional_background_order, columns=[0, 1], fill_value=0)

        print(f"\nPlatform Group: {group}")
        #print(f"Binary Contingency Table (for chi-squared test):\n{contingency_table_binary}\n")

        # Perform chi-squared test
        non_zero_rows_binary = (contingency_table_binary != 0).any(axis=1).sum()
        non_zero_cols_binary = (contingency_table_binary != 0).any(axis=0).sum()
        if non_zero_rows_binary < 2 or non_zero_cols_binary < 2:
            print(f"Skipping chi-squared test for {group}: Binary contingency table is degenerate (fewer than 2 non-zero rows or columns).")
            chi2, p, cramers_v = None, None, None
        else:
            chi2, p, dof, expected = chi2_contingency(contingency_table_binary)
            if (expected < 1).any():
                print(f"Skipping chi-squared test for {group}: Expected frequencies contain values less than 1.")
                chi2, p, cramers_v = None, None, None
            else:
                if (expected < 5).any():
                    print("Warning: Some expected frequencies are less than 5, chi-squared test may be unreliable.")
                n = contingency_table_binary.sum().sum()
                cramers_v = np.sqrt(chi2 / (n * (min(contingency_table_binary.shape) - 1)))
                print(f"Chi-Squared Statistic: {chi2:.3f}")
                print(f"P-Value: {p:.3f}")
                print(f"Cramér's V: {cramers_v:.3f}")
                if p < 0.05:
                    print("Result: There is a significant association between professional background and this platform group (p < 0.05).\n")
                else:
                    print("Result: There is no significant association between professional background and this platform group (p >= 0.05).\n")

        # Create contingency table for visualization (including 'unknown')
        contingency_table = pd.crosstab(df_copy2['professional_background_str'], df_copy2[group_status])
        contingency_table = contingency_table.reindex(index=professional_background_order, columns=status_order, fill_value=0)

        #print(f"Contingency Table:\n{contingency_table}\n")

        # Check for degenerate visualization table
        non_zero_rows_viz = (contingency_table != 0).any(axis=1).sum()
        non_zero_cols_viz = (contingency_table != 0).any(axis=0).sum()
        if non_zero_rows_viz < 2 or non_zero_cols_viz < 2:
            print(f"Skipping visualization for {group}: Visualization contingency table is degenerate (fewer than 2 non-zero rows or columns).")
            viz_skipped = True
        else:
            viz_skipped = False

        # Store contingency table with test results
        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Platform Group'] = group
        contingency_table_reset['Chi2'] = chi2 if chi2 is not None else 'N/A'
        contingency_table_reset['P-Value'] = p if p is not None else 'N/A'
        contingency_table_reset["Cramér's V"] = cramers_v if cramers_v is not None else 'N/A'
        platform_groups_contingency_tables.append(contingency_table_reset)

        # Visualize only if not degenerate
        if not viz_skipped:
            plt.figure(figsize=(8, 6))
            sns.countplot(
                data=df_copy2, 
                x='professional_background_str', 
                hue=group_status, 
                hue_order=status_order, 
                palette='Set2', 
                order=professional_background_order
            )
            plt.title(f'Professional Background vs. {group} Usage')
            plt.xlabel('Professional Background')
            plt.ylabel('Count')
            plt.legend(title='Usage Status', labels=['Used', 'Not Used', 'Unknown'])
            plt.xticks(rotation=45)
            plt.tight_layout()
            filename = f"{output_dir}/professional_background_str_vs_{sanitize_filename(group)}_stacked_bar.png"
            plt.savefig(filename)
            plt.close()
            print(f"Saved plot: {filename}")
        else:
            print(f"Plot not generated for {group} due to degenerate visualization table.")

    except Exception as e:
        print(f"Failed to process {group}: {e}\n")
        plt.close()
        continue

# Save contingency tables to Excel
if platform_groups_contingency_tables:
    all_platform_tables_df = pd.concat(platform_groups_contingency_tables, ignore_index=True)
    cols = ['Platform Group', 'Chi2', 'P-Value', "Cramér's V"] + [col for col in all_platform_tables_df.columns if col not in ['Platform Group', 'Chi2', 'P-Value', "Cramér's V"]]
    all_platform_tables_df = all_platform_tables_df[cols]
    output_xlsx = '/kaggle/working/profession/platform_groups/platform_groups_contingency_tables.xlsx'
    all_platform_tables_df.to_excel(output_xlsx, index=False)
    print(f"Saved platform groups contingency tables to: {output_xlsx}")
else:
    print("No platform groups contingency tables to save.")

# Create a ZIP file for plots
zip_filename = '/kaggle/working/profession/platform_groups/plots_platform_groups.zip'
print(f"Updating ZIP file: {zip_filename}...")

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.png'):
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, '/kaggle/working/')
                zipf.write(file_path, arcname)

print(f"ZIP file updated: {zip_filename}")

print("Chi-Squared Test and Bar Plots for Professional Background vs. Grouped Platforms completed.")
# Out:
# Mappings for 'not used' and 'unknown' values in platform_groups:
#
# Platform Group: general e-commerce platforms
# Not Used Value: None
# Unknown Value: None
#
# Platform Group: specialty online stores / automobile
# Not Used Value: zero specialty online stores / automobile
# Unknown Value: specialty online stores / automobile unknown
#
# Platform Group: online pharmacies
# Not Used Value: no online pharmacies
# Unknown Value: online pharmacy unknown
#
# Platform Group: fashion and beauty retailers
# Not Used Value: no fashion and beauty retailers
# Unknown Value: unknown fashion and beauty retailers
#
# Platform Group: grocery delivery services
# Not Used Value: grocery delivery services not used
# Unknown Value: unknown grocery delivery services
#
# Platform Group: general e-commerce platforms
# Skipping chi-squared test for general e-commerce platforms: Binary contingency table is degenerate (fewer than 2 non-zero rows or columns).
# Skipping visualization for general e-commerce platforms: Visualization contingency table is degenerate (fewer than 2 non-zero rows or columns).
# Plot not generated for general e-commerce platforms due to degenerate visualization table.
#
# Platform Group: specialty online stores / automobile
# Skipping chi-squared test for specialty online stores / automobile: Expected frequencies contain values less than 1.
# Saved plot: /kaggle/working/profession/platform_groups/plots/professional_background_str_vs_specialty_online_stores___automobile_stacked_bar.png
#
# Platform Group: online pharmacies
# Skipping chi-squared test for online pharmacies: Expected frequencies contain values less than 1.
# Saved plot: /kaggle/working/profession/platform_groups/plots/professional_background_str_vs_online_pharmacies_stacked_bar.png
#
# Platform Group: fashion and beauty retailers
# Skipping chi-squared test for fashion and beauty retailers: Expected frequencies contain values less than 1.
# Saved plot: /kaggle/working/profession/platform_groups/plots/professional_background_str_vs_fashion_and_beauty_retailers_stacked_bar.png
#
# Platform Group: grocery delivery services
# Skipping chi-squared test for grocery delivery services: Expected frequencies contain values less than 1.
# Saved plot: /kaggle/working/profession/platform_groups/plots/professional_background_str_vs_grocery_delivery_services_stacked_bar.png
# Saved platform groups contingency tables to: /kaggle/working/profession/platform_groups/platform_groups_contingency_tables.xlsx
# Updating ZIP file: /kaggle/working/profession/platform_groups/plots_platform_groups.zip...
# ZIP file updated: /kaggle/working/profession/platform_groups/plots_platform_groups.zip
# Chi-Squared Test and Bar Plots for Professional Background vs. Grouped Platforms completed.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import zipfile
import warnings
from scipy.stats import chi2_contingency
import numpy as np

warnings.filterwarnings('ignore')

output_dir = '/kaggle/working/profession/platform_groups/plots'
os.makedirs(output_dir, exist_ok=True)

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')

prof_background_mapping = {
    0: 'Employed (full-time)',
    1: 'Employed (part-time)',
    2: 'Student',
    3: 'Unemployed',
    4: 'Self-employed / Entrepreneur'
}
df_copy2['professional_background_str'] = df_copy2['professional background'].map(prof_background_mapping)

professional_background_order = [
    'Employed (full-time)', 'Employed (part-time)', 'Student', 'Unemployed', 
    'Self-employed / Entrepreneur'
]

platform_groups = [
    'general e-commerce platforms', 'specialty online stores / automobile', 'online pharmacies', 
    'fashion and beauty retailers', 'grocery delivery services'
]

not_used_values = {
    'general e-commerce platforms': None,
    'specialty online stores / automobile': 'zero specialty online stores / automobile',
    'online pharmacies': 'no online pharmacies',
    'fashion and beauty retailers': 'no fashion and beauty retailers',
    'grocery delivery services': 'grocery delivery services not used'
}

unknown_values = {
    'general e-commerce platforms': None,
    'specialty online stores / automobile': 'specialty online stores / automobile unknown',
    'online pharmacies': 'online pharmacy unknown',
    'fashion and beauty retailers': 'unknown fashion and beauty retailers',
    'grocery delivery services': 'unknown grocery delivery services'
}

for group in platform_groups:
    df_copy2[f'{group}_status'] = df_copy2[group].apply(
        lambda x: 'unknown' if pd.isna(x) or (group in unknown_values and x == unknown_values[group])
        else 'not used' if group in not_used_values and x == not_used_values[group]
        else 'used'
    )

platform_group_status = [f'{group}_status' for group in platform_groups]
status_order = ['used', 'not used', 'unknown']

print("Mappings for 'not used' and 'unknown' values in platform_groups:")
for group in platform_groups:
    print(f"\nPlatform Group: {group}")
    print(f"Not Used Value: {not_used_values[group]}")
    print(f"Unknown Value: {unknown_values[group]}")

platform_groups_contingency_tables = []

for group in platform_groups:
    group_status = f'{group}_status'
    try:
        contingency_table = pd.crosstab(df_copy2['professional_background_str'], df_copy2[group_status])
        contingency_table = contingency_table.reindex(index=professional_background_order, columns=status_order, fill_value=0)

        print(f"\nPlatform Group: {group}")
        #print(f"Contingency Table:\n{contingency_table}\n")

        # Perform chi-squared test
        if (contingency_table_binary == 0).any().any():
            print(f"\nSkipping chi-squared test for {group}: Contingency table has empty categories.")
            chi2, p, cramers_v = None, None, None
        else:
            chi2, p, dof, expected = chi2_contingency(contingency_table_binary)
            if (expected < 1).any():
                print(f"Skipping chi-squared test for {group}: Expected frequencies contain values less than 1.")
                chi2, p, cramers_v = None, None, None
            else:
                n = contingency_table_binary.sum().sum()
                cramers_v = np.sqrt(chi2 / (n * (min(contingency_table_binary.shape) - 1)))
                print(f"\nPlatform Group: {group}")
                print(f"Chi-Squared Statistic: {chi2:.3f}")
                print(f"P-Value: {p:.3f}")
                print(f"Cramér's V: {cramers_v:.3f}")
                if p < 0.05:
                    print("Result: There is a significant association between professional background and this platform group (p < 0.05).")
                else:
                    print("Result: There is no significant association between professional background and this platform group (p >= 0.05).")


        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Platform Group'] = group
        contingency_table_reset['Chi2'] = chi2 if chi2 is not None else 'N/A'
        contingency_table_reset['P-Value'] = p if p is not None else 'N/A'
        contingency_table_reset["Cramér's V"] = cramers_v if cramers_v is not None else 'N/A'
        platform_groups_contingency_tables.append(contingency_table_reset)

        plt.figure(figsize=(8, 6))
        sns.countplot(
            data=df_copy2, 
            x='professional_background_str', 
            hue=group_status, 
            hue_order=status_order, 
            palette='Set2', 
            order=professional_background_order
        )
        plt.title(f'Professional Background vs. {group} Usage')
        plt.xlabel('Professional Background')
        plt.ylabel('Count')
        plt.legend(title='Usage Status', labels=['Used', 'Not Used', 'Unknown'])
        plt.xticks(rotation=45)
        plt.tight_layout()
        filename = f"{output_dir}/professional_background_str_vs_{sanitize_filename(group)}_stacked_bar.png"
        plt.savefig(filename)
        plt.close()
        #print(f"Saved plot: {filename}")

    except Exception as e:
        print(f"Failed to process {group}: {e}\n")
        plt.close()
        continue

# Save contingency tables to Excel
if platform_groups_contingency_tables:
    all_platform_tables_df = pd.concat(platform_groups_contingency_tables, ignore_index=True)
    cols = ['Platform Group', 'Chi2', 'P-Value', "Cramér's V"] + [col for col in all_platform_tables_df.columns if col not in ['Platform Group', 'Chi2', 'P-Value', "Cramér's V"]]
    all_platform_tables_df = all_platform_tables_df[cols]
    output_xlsx = '/kaggle/working/profession/platform_groups/platform_groups_contingency_tables.xlsx'
    all_platform_tables_df.to_excel(output_xlsx, index=False)
    print(f"Saved platform groups contingency tables to: {output_xlsx}")
else:
    print("No platform groups contingency tables to save.")

zip_filename = '/kaggle/working/profession/platform_groups/plots_platform_groups.zip'
print(f"Updating ZIP file: {zip_filename}...")

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.png'):
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, '/kaggle/working/')
                zipf.write(file_path, arcname)

print(f"ZIP file updated: {zip_filename}")

print("Chi-Squared Test and Bar Plots for Professional Background vs. Grouped Platforms (Including Unknown) completed.")
# Out:
# Mappings for 'not used' and 'unknown' values in platform_groups:
#
# Platform Group: general e-commerce platforms
# Not Used Value: None
# Unknown Value: None
#
# Platform Group: specialty online stores / automobile
# Not Used Value: zero specialty online stores / automobile
# Unknown Value: specialty online stores / automobile unknown
#
# Platform Group: online pharmacies
# Not Used Value: no online pharmacies
# Unknown Value: online pharmacy unknown
#
# Platform Group: fashion and beauty retailers
# Not Used Value: no fashion and beauty retailers
# Unknown Value: unknown fashion and beauty retailers
#
# Platform Group: grocery delivery services
# Not Used Value: grocery delivery services not used
# Unknown Value: unknown grocery delivery services
#
# Platform Group: general e-commerce platforms
#
# Skipping chi-squared test for general e-commerce platforms: Contingency table has empty categories.
#
# Platform Group: specialty online stores / automobile
#
# Skipping chi-squared test for specialty online stores / automobile: Contingency table has empty categories.
#
# Platform Group: online pharmacies
#
# Skipping chi-squared test for online pharmacies: Contingency table has empty categories.
#
# Platform Group: fashion and beauty retailers
#
# Skipping chi-squared test for fashion and beauty retailers: Contingency table has empty categories.
#
# Platform Group: grocery delivery services
#
# Skipping chi-squared test for grocery delivery services: Contingency table has empty categories.
# Saved platform groups contingency tables to: /kaggle/working/profession/platform_groups/platform_groups_contingency_tables.xlsx
# Updating ZIP file: /kaggle/working/profession/platform_groups/plots_platform_groups.zip...
# ZIP file updated: /kaggle/working/profession/platform_groups/plots_platform_groups.zip
# Chi-Squared Test and Bar Plots for Professional Background vs. Grouped Platforms (Including Unknown) completed.

# %% [markdown]
# ## Professional Background vs Other Features

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
import zipfile
import warnings

warnings.filterwarnings('ignore')

output_dir = '/kaggle/working/profession/other_features/plots'
os.makedirs(output_dir, exist_ok=True)

def sanitize_filename(name):
    return re.sub(r'[^\w\s.-]', '_', name.replace('/', '_').replace('.', '_')).replace(' ', '_')

prof_background_mapping = {
    0: 'Employed (full-time)',
    1: 'Employed (part-time)',
    2: 'Student',
    3: 'Unemployed',
    4: 'Self-employed / Entrepreneur'
}

df_copy2['profession_str'] = df_copy2['professional background'].map(prof_background_mapping)

professional_background_order = ['Employed (full-time)', 'Employed (part-time)', 'Student', 'Unemployed', 'Self-employed / Entrepreneur']

agreement_mapping = {
    0: 'Strongly Disagree',
    1: 'Disagree',
    2: 'Neutral',
    3: 'Agree',
    4: 'Strongly Agree'
}

# Define order for agreement levels
agreement_order = ['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree']

for feature in other_features:
    df_copy2[f'{feature}_str'] = df_copy2[feature].map(agreement_mapping)

other_features_str = [f'{feature}_str' for feature in other_features]

other_features_contingency_tables = []

for feature_str in other_features_str:
    try:
        contingency_table = pd.crosstab(df_copy2['profession_str'], df_copy2[feature_str])
        
        contingency_table = contingency_table.reindex(professional_background_order)
        contingency_table = contingency_table.reindex(columns=agreement_order, fill_value=0)

        # Store contingency table
        contingency_table_reset = contingency_table.reset_index()
        contingency_table_reset['Feature'] = feature_str.replace('_str', '')  
        other_features_contingency_tables.append(contingency_table_reset)

        plt.figure(figsize=(8, 6))
        sns.countplot(
            data=df_copy2, 
            x='profession_str', 
            hue=feature_str, 
            hue_order=agreement_order, 
            palette='Set2', 
            order=professional_background_order
        )
        plt.title(f'Professional Background vs. {feature_str.replace("_str", "")}')
        plt.xlabel('Marital Status')
        plt.ylabel('Count')
        plt.legend(title='Agreement Level')
        plt.xticks(rotation=30)
        plt.tight_layout()
        filename = f"{output_dir}/professional_background_vs_{sanitize_filename(feature_str)}_stacked_bar.png"
        plt.savefig(filename)
        plt.close()
        print(f"Saved plot: {filename}")
    except Exception as e:
        print(f"Failed to process {feature_str}: {e}")
        plt.close()
        continue

if other_features_contingency_tables:
    all_other_features_tables_df = pd.concat(other_features_contingency_tables, ignore_index=True)
    
    cols = ['Feature', 'profession_str'] + agreement_order
    all_other_features_tables_df = all_other_features_tables_df[cols]
    output_xlsx = '/kaggle/working/profession/other_features/other_features_contingency_tables.xlsx'
    all_other_features_tables_df.to_excel(output_xlsx, index=False)
    print(f"Saved other features contingency tables to: {output_xlsx}")
else:
    print("No other features contingency tables to save.")

zip_filename = '/kaggle/working/profession/other_features/plots-other_features-association.zip'
print(f"Updating ZIP file: {zip_filename}...")

with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(output_dir):
        for file in files:
            if file.endswith('.png'):
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, '/kaggle/working/')
                zipf.write(file_path, arcname)

print(f"ZIP file updated: {zip_filename}")

print("EDA for professional_background vs. Other Features completed. Plots saved as PNG files")
# Out:
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_it_is_easy_to_navigate_through_the_online_platform_to_find_the_products_or_services_i_need_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_the_online_platform_provides_clear_and_intuitive_navigation_options_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_it_was_easy_for_me_to_learn_how_to_use_the_online_platform_for_making_online_purchases_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_quickly_became_proficient_in_using_the_online_platform_for_making_online_purchases_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_the_instructions_provided_on_the_online_platform_are_clear_and_easy_to_understand_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_can_easily_follow_the_instructions_given_on_the_online_platform_for_making_online_purchases_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_the_online_platform_responds_quickly_to_my_actions__such_as_loading_pages_and_processing_transactions__str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_don_t_experience_delays_or_long_waiting_times_when_using_the_online_platform_for_making_online_purchases_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_the_online_platform_effectively_handles_errors_or_mistakes__such_as_providing_clear_error_messages_and_easy_recovery_options_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_rarely_encounter_errors_or_issues_when_using_the_online_platform_for_making_online_purchases_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_the_online_platform_offers_a_wide_range_of_products_and_services_that_meet_my_needs_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_can_find_the_products_or_services_i_need_on_the_online_platform_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_using_the_online_platform_for_making_purchases_during_a_crisis_is_convenient_and_saves_time_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_the_online_platform_makes_it_easy_to_search_for_products_and_complete_transactions_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_the_online_platform_offers_competitive_prices__discounts__or_cost-saving_benefits_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_perceive_that_using_the_online_platform_for_making_purchases_during_a_crisis_can_help_me_save_money_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_the_online_platform_provides_detailed_and_accurate_product_information_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_can_easily_access_user_reviews__ratings__and_other_relevant_information_to_support_my_purchase_decisions_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_the_online_platform_tailors_recommendations__suggestions__or_personalized_offers_based_on_my_preferences_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_feel_that_the_online_platform_understands_my_needs_and_preferences_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_the_online_platform_takes_appropriate_measures_to_protect_my_privacy_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_trust_that_my_personal_information_will_be_handled_securely_by_the_online_platform_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_the_online_platform_provides_secure_payment_methods_to_protect_against_fraudulent_activities_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_trust_that_my_payment_details_are_handled_securely_by_the_online_platform_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_the_online_platform_provides_clear_and_easily_accessible_policies_regarding_data_handling__privacy__and_security_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_feel_confident_in_the_online_platform_s_transparency_regarding_its_data_protection_practices_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_am_influenced_by_recommendations_and_opinions_from_family_and_friends_when_making_online_purchases_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_consider_the_experiences_and_suggestions_shared_by_people_i_know_before_making_online_purchases_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_during_a_crisis__social_media_platforms__influencers__and_online_communities_influence_my_online_purchase_decisions_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_am_likely_to_make_online_purchases_during_a_crisis_based_on_what_i_see_or_learn_from_social_media_platforms_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_consider_online_reviews_and_ratings_when_making_purchasing_decisions_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_positive_reviews_and_high_ratings_increase_my_confidence_in_making_online_purchases_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_observing_others_making_online_purchases_during_a_crisis_influences_my_own_intention_to_make_similar_purchases_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_am_more_likely_to_make_online_purchases_during_a_crisis_if_i_see_others_doing_the_same_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_social_norms_and_expectations_regarding_online_shopping_during_a_crisis_influence_my_own_intention_to_make_online_purchases_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_feel_pressure_to_make_online_purchases_during_a_crisis_due_to_the_expectations_of_others_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_am_willing_to_share_my_own_online_shopping_experiences__recommendations__or_opinions_with_others_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_sharing_information_about_my_online_purchases_during_a_crisis_is_important_for_influencing_others__purchase_decisions_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_overall__i_have_a_positive_attitude_toward_online_shopping_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_believe_that_online_shopping_is_a_practical_and_efficient_way_to_make_purchases_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_am_concerned_about_the_security_of_my_personal_and_financial_information_when_shopping_online_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_am_cautious_about_the_reliability_and_authenticity_of_products_or_services_offered_by_online_platforms_during_a_crisis_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_overall__i_am_satisfied_with_online_purchase_during_a_crisis__str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_have_changed_my_online_shopping_behavior_during_a_crisis_compared_to_non-crisis_periods__str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_it_was_convenient_for_me_to_do_online_shopping_during_a_crisis_compared_to_traditional_in-store_shopping_str_stacked_bar.png
# Saved plot: /kaggle/working/profession/other_features/plots/professional_background_vs_i_believe_that_online_shopping_during_a_crisis_offers_better_value_for_money_compared_to_traditional_shopping_methods_str_stacked_bar.png
# Saved other features contingency tables to: /kaggle/working/profession/other_features/other_features_contingency_tables.xlsx
# Updating ZIP file: /kaggle/working/profession/other_features/plots-other_features-association.zip...
# ZIP file updated: /kaggle/working/profession/other_features/plots-other_features-association.zip
# EDA for professional_background vs. Other Features completed. Plots saved as PNG files
